# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # To run Chrome in headless mode

# Set up the Chrome driver
chrome_driver_path = 'C:/Users/ASUS/Downloads/chromedriver.exe'  # Update with your Chrome driver path
service = Service(chrome_driver_path)
driver = webdriver.Chrome(service=service, options=chrome_options)

# Open the website
url = "https://www.caradisiac.com/constructeurs--automobiles/"
driver.get(url)

# Wait for the page to load
time.sleep(5)  # Adjust the sleep time as needed

# Define the alphabet range from 'A' to 'Z'
alphabet_range = [chr(i) for i in range(ord('A'), ord('Z') + 1)]

# Initialize an empty list to store car makes
car_makes = []

# Loop through each letter in the alphabet range
for letter in alphabet_range:
    # Construct the ID dynamically
    list_id = f"list_{letter}"
    
    # Check if the element with the constructed ID exists
    try:
        car_make_div = driver.find_element(By.ID, list_id)
        
        # Find all the <a> elements within the div
        car_make_links = car_make_div.find_elements(By.TAG_NAME, 'a')
        
        # Extract the marque names from the 'title' attribute of each <a> element
        car_makes.extend([link.get_attribute('title') for link in car_make_links])
    except:
        pass

# Print the list of car makes
for make in car_makes:
    print(make)

# Close the browser
driver.quit()
# Out:
# Abarth
# Abarth
# Ac
# Ac
# Acrea
# Acrea
# Acura
# Acura
# Ad Tramontana
# Ad Tramontana
# Adler
# Adler
# Aiways
# Aiways
# Aixam
# Aixam
# Al Melling
# Al Melling
# Aleko
# Aleko
# Alfa Romeo
# Alfa Romeo
# Alke
# Alke
# Alpina
# Alpina
# Alpine
# Alpine
# Alvis
# Alvis
# Am General
# Am General
# Amc
# Amc
# Amphicar
# Amphicar
# Anaig
# Anaig
# Apal
# Apal
# Aptera Motors
# Aptera Motors
# Ariel
# Ariel
# Armstrong Siddeley
# Armstrong Siddeley
# Aro
# Aro
# Artega
# Artega
# Ascari
# Ascari
# Aspark
# Aspark
# Aston Martin
# Aston Martin
# Auburn
# Auburn
# Audi
# Audi
# Austin
# Austin
# Austin Healey
# Austin Healey
# Auto Union
# Auto Union
# Autobianchi
# Autobianchi
# Auverland
# Auverland
# Bee Automobiles
# Bee Automobiles
# Bellier
# Bellier
# Bentley
# Bentley
# Berliet
# Berliet
# Bertone
# Bertone
# Bitter
# Bitter
# Bizzarrini
# Bizzarrini
# Bluecar Groupe Bollore
# Bluecar Groupe Bollore
# Bmw
# Bmw
# Bollore
# Bollore
# Bongarini
# Bongarini
# Booxt
# Booxt
# Borgward
# Borgward
# Bowler
# Bowler
# Brabus
# Brabus
# Bremach
# Bremach
# Brilliance
# Brilliance
# Bristol
# Bristol
# Brooke Cars
# Brooke Cars
# Bugatti
# Bugatti
# Buick
# Buick
# Burby S
# Burby S
# Byd
# Byd
# Cadillac
# Cadillac
# Caparo
# Caparo
# Carbodies
# Carbodies
# Carbontech
# Carbontech
# Carver
# Carver
# Casalini
# Casalini
# Caterham
# Caterham
# Cg
# Cg
# Chatenet
# Chatenet
# Chenard Et Walcker
# Chenard Et Walcker
# Chery
# Chery
# Chevrolet
# Chevrolet
# China Automobile
# China Automobile
# Chrysler
# Chrysler
# Citroen
# Citroen
# Clenet
# Clenet
# Commuter Cars
# Commuter Cars
# Connaught
# Connaught
# Coste
# Coste
# Courb
# Courb
# Cupra
# Cupra
# Curbee
# Curbee
# Dacia
# Dacia
# Daewoo
# Daewoo
# Daf
# Daf
# Daihatsu
# Daihatsu
# Daimler
# Daimler
# Dallara
# Dallara
# Dangel
# Dangel
# Darmont
# Darmont
# Datsun
# Datsun
# De Fremond
# De Fremond
# De La Chapelle
# De La Chapelle
# De Lorean
# De Lorean
# De Soto
# De Soto
# De Tomaso
# De Tomaso
# Delage
# Delage
# Delahaye
# Delahaye
# Denza
# Denza
# Deronda
# Deronda
# Deutsch-bonnet
# Deutsch-bonnet
# Devinci
# Devinci
# Devon
# Devon
# Dfsk
# Dfsk
# Dkw
# Dkw
# Dodge
# Dodge
# Dongfeng
# Dongfeng
# Donkervoort
# Donkervoort
# Donnet
# Donnet
# Dr Motor
# Dr Motor
# Ds
# Ds
# Due
# Due
# Duesenberg
# Duesenberg
# Eagle
# Eagle
# Ebro
# Ebro
# Edsel
# Edsel
# Elv
# Elv
# Embuggy
# Embuggy
# Erad
# Erad
# Estrima
# Estrima
# Exagon Motors
# Exagon Motors
# Excalibur
# Excalibur
# Facel Vega
# Facel Vega
# Fam Automobiles
# Fam Automobiles
# Faraday Future
# Faraday Future
# Faralli & Mazzanti
# Faralli & Mazzanti
# Farbio
# Farbio
# Ferrari
# Ferrari
# Fest
# Fest
# Fiat
# Fiat
# Fioravanti
# Fioravanti
# Fisker
# Fisker
# Ford
# Ford
# Fornasari
# Fornasari
# Fso
# Fso
# Gac Gonow
# Gac Gonow
# Gac Motor
# Gac Motor
# Geely
# Geely
# Genesis
# Genesis
# Gillet
# Gillet
# Ginetta
# Ginetta
# Glas
# Glas
# Gmc
# Gmc
# Gme
# Gme
# Goupil
# Goupil
# Grandin
# Grandin
# Great Wall
# Great Wall
# Grecav
# Grecav
# Gumpert
# Gumpert
# Healey
# Healey
# Helem
# Helem
# Hennessey
# Hennessey
# Heuliez
# Heuliez
# Hillman
# Hillman
# Hispano Suiza Cars
# Hispano Suiza Cars
# Holden
# Holden
# Hommell
# Hommell
# Honda
# Honda
# Hopium
# Hopium
# Hotchkiss
# Hotchkiss
# Howmet
# Howmet
# Hudson
# Hudson
# Humber
# Humber
# Hummer
# Hummer
# Hyundai
# Hyundai
# Imperial
# Imperial
# Ineos
# Ineos
# Infiniti
# Infiniti
# Innocenti
# Innocenti
# Innotech
# Innotech
# Intermeccanica
# Intermeccanica
# International
# International
# Invicta
# Invicta
# Iso
# Iso
# Isorivolta
# Isorivolta
# Isuzu
# Isuzu
# Italcar
# Italcar
# Iveco
# Iveco
# Jaguar
# Jaguar
# Jdm Simpa
# Jdm Simpa
# Jeep
# Jeep
# Jensen
# Jensen
# Jiayuan
# Jiayuan
# Karma
# Karma
# Kassbohrer Setra
# Kassbohrer Setra
# Kia
# Kia
# Koenigsegg
# Koenigsegg
# Ktm
# Ktm
# Lada
# Lada
# Lagonda
# Lagonda
# Lamborghini
# Lamborghini
# Lancia
# Lancia
# Land Rover
# Land Rover
# Landwind
# Landwind
# Lantana
# Lantana
# Laraki
# Laraki
# Ldv
# Ldv
# Leapmotor
# Leapmotor
# Levc
# Levc
# Lexus
# Lexus
# Lightyear
# Lightyear
# Ligier
# Ligier
# Lincoln
# Lincoln
# Lister
# Lister
# Little
# Little
# Lola
# Lola
# London Taxi Company
# London Taxi Company
# Loremo
# Loremo
# Lotus
# Lotus
# Lucid
# Lucid
# Lumeneo
# Lumeneo
# Lynk & Co
# Lynk & Co
# Mahindra
# Mahindra
# Man
# Man
# Marcadier
# Marcadier
# Marcos
# Marcos
# Martin
# Martin
# Marussia
# Marussia
# Maruti
# Maruti
# Maserati
# Maserati
# Matra
# Matra
# Maxus
# Maxus
# Maybach
# Maybach
# Mazda
# Mazda
# Mclaren
# Mclaren
# Mdi
# Mdi
# Mega
# Mega
# Melkus
# Melkus
# Mercedes
# Mercedes
# Mercedes-amg
# Mercedes-amg
# Mercury
# Mercury
# Messerschmitt
# Messerschmitt
# Mev
# Mev
# Meyers Manx
# Meyers Manx
# Mg
# Mg
# Mia Electric
# Mia Electric
# Micro
# Micro
# Microcar
# Microcar
# Microdrive
# Microdrive
# Minauto
# Minauto
# Mini
# Mini
# Mitsubishi
# Mitsubishi
# Mitsubishi Fuso
# Mitsubishi Fuso
# Mitsuoka
# Mitsuoka
# Mlt
# Mlt
# Mobilize
# Mobilize
# Moke
# Moke
# Monteverdi
# Monteverdi
# Morgan
# Morgan
# Morris
# Morris
# Mosler
# Mosler
# Mpm Motors
# Mpm Motors
# Munro
# Munro
# Mvs
# Mvs
# Mygale
# Mygale
# Namx
# Namx
# Nanjing
# Nanjing
# Nash
# Nash
# Neckar
# Neckar
# Newteon
# Newteon
# Newyark
# Newyark
# Nio
# Nio
# Nissan
# Nissan
# Noble
# Noble
# Nosmoke
# Nosmoke
# Noun Electric
# Noun Electric
# Nsu
# Nsu
# Numexia
# Numexia
# Oldsmobile
# Oldsmobile
# Opel
# Opel
# Ora
# Ora
# Osi
# Osi
# Packard
# Packard
# Pagani
# Pagani
# Panhard
# Panhard
# Panoz
# Panoz
# Panther
# Panther
# Pegaso
# Pegaso
# Perana
# Perana
# Peugeot
# Peugeot
# Pgo
# Pgo
# Piaggio
# Piaggio
# Pilbeam
# Pilbeam
# Pininfarina
# Pininfarina
# Plymouth
# Plymouth
# Polestar
# Polestar
# Polski
# Polski
# Pontiac
# Pontiac
# Porsche
# Porsche
# Proton
# Proton
# Protoscar
# Protoscar
# Qoros
# Qoros
# Quant
# Quant
# Radical
# Radical
# Ram
# Ram
# Rcb
# Rcb
# Realm
# Realm
# Reliant
# Reliant
# Renault
# Renault
# Renault Trucks
# Renault Trucks
# Rene Bonnet
# Rene Bonnet
# Reva
# Reva
# Reynard
# Reynard
# Riley
# Riley
# Rimac
# Rimac
# Rinspeed
# Rinspeed
# Rivian
# Rivian
# Rolls Royce
# Rolls Royce
# Ronart
# Ronart
# Rosengart
# Rosengart
# Rover
# Rover
# Russo-baltique
# Russo-baltique
# Saab
# Saab
# Saic
# Saic
# Saleen
# Saleen
# Salica
# Salica
# Salmson
# Salmson
# Samsung
# Samsung
# Santana
# Santana
# Saturn
# Saturn
# Savel
# Savel
# Saviem
# Saviem
# Sbarro
# Sbarro
# Scania
# Scania
# Scion
# Scion
# Seat
# Seat
# Secma
# Secma
# Seres
# Seres
# Shelby
# Shelby
# Shuanghuan
# Shuanghuan
# Simca
# Simca
# Singer
# Singer
# Sivax
# Sivax
# Skoda
# Skoda
# Smart
# Smart
# Sms
# Sms
# Sovamag
# Sovamag
# Spectre
# Spectre
# Spyker
# Spyker
# Srt
# Srt
# Ssangyong
# Ssangyong
# Ssc
# Ssc
# Studebaker
# Studebaker
# Stutz
# Stutz
# Subaru
# Subaru
# Sunbeam
# Sunbeam
# Suzuki
# Suzuki
# Talbot
# Talbot
# Talbot Simca
# Talbot Simca
# Tata
# Tata
# Teilhol
# Teilhol
# Tesla
# Tesla
# Think
# Think
# Toyota
# Toyota
# Trabant
# Trabant
# Triumph
# Triumph
# Tvr
# Tvr
# Ultima
# Ultima
# Umm
# Umm
# Vaillante
# Vaillante
# Van Hool
# Van Hool
# Vanden Plas
# Vanden Plas
# Vauxhall
# Vauxhall
# Velam
# Velam
# Venturi
# Venturi
# Veritas
# Veritas
# Vespa
# Vespa
# Vinfast
# Vinfast
# Virago
# Virago
# Volkswagen
# Volkswagen
# Volteis
# Volteis
# Volvo
# Volvo
# Volvo Trucks
# Volvo Trucks
# Wallys Car
# Wallys Car
# Westfield
# Westfield
# Wiesmann
# Wiesmann
# Willys
# Willys
# Wolseley
# Wolseley
# Xev
# Xev
# Xiaomi
# Xiaomi
# Xinyang
# Xinyang
# Xpeng
# Xpeng
# Yangwang
# Yangwang
# Zagato
# Zagato
# Zap
# Zap
# Zastava
# Zastava
# Zeekr
# Zeekr
# Zenn
# Zenn
# Zenvo
# Zenvo

# %%
import pandas as pd
# Create a dataframe with the scraped marque names
df = pd.DataFrame({'marques': car_makes})

# Print the dataframe
print(df)
# Out:
#     marques
# 0    Abarth
# 1    Abarth
# 2        Ac
# 3        Ac
# 4     Acrea
# ..      ...
# 769   Zeekr
# 770    Zenn
# 771    Zenn
# 772   Zenvo
# 773   Zenvo
#
# [774 rows x 1 columns]

# %%
df.duplicated(subset= ['marques']).sum()
# Out:
# 387

# %%
df.drop_duplicates(subset= ['marques'],keep= 'first', inplace= True)

# %%
df
# Out:
#            marques
# 0           Abarth
# 2               Ac
# 4            Acrea
# 6            Acura
# 8    Ad Tramontana
# ..             ...
# 764            Zap
# 766        Zastava
# 768          Zeekr
# 770           Zenn
# 772          Zenvo
#
# [387 rows x 1 columns]

# %%
def process_brand(row):
    return row['marques'].lower().replace(' ', '-')

df['brands'] = df.apply(process_brand, axis=1)

# %%
df['brands']
# Out:
# 0             abarth
# 2                 ac
# 4              acrea
# 6              acura
# 8      ad-tramontana
#            ...
# 764              zap
# 766          zastava
# 768            zeekr
# 770             zenn
# 772            zenvo
# Name: brands, Length: 387, dtype: object

# %%
'''
# Function to scrape models for a given brand name
def scrape_models(brand_name):
    models = []

    # Standard URL template
    url_template = "https://www.caradisiac.com/auto--{}/modeles/"
    brand_link = url_template.format(brand_name)

    # Make a GET request to the brand link
    response = requests.get(brand_link)
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        # Find all the elements containing model names
        model_elements = soup.select('#JSContent > section:nth-child(4) > div.main.padResponsive > div:nth-child(2) > ul > li:nth-child(1) > div.txtModeleGalerie > div > a > p')
        # Extract model names
        models = [element.text.strip() for element in model_elements]

    return models
'''
# Out:
# '\n# Function to scrape models for a given brand name\ndef scrape_models(brand_name):\n    models = []\n\n    # Standard URL template\n    url_template = "https://www.caradisiac.com/auto--{}/modeles/"\n    brand_link = url_template.format(brand_name)\n\n    # Make a GET request to the brand link\n    response = requests.get(brand_link)\n    if response.status_code == 200:\n        # Parse the HTML content\n        soup = BeautifulSoup(response.content, \'html.parser\')\n        # Find all the elements containing model names\n        model_elements = soup.select(\'#JSContent > section:nth-child(4) > div.main.padResponsive > div:nth-child(2) > ul > li:nth-child(1) > div.txtModeleGalerie > div > a > p\')\n        # Extract model names\n        models = [element.text.strip() for element in model_elements]\n\n    return models\n'

# %%
# List of brand names
brand_names = []
for brand in df["brands"]:
    brand_names.append(brand)
brand_names
# Out:
# ['abarth',
#  'ac',
#  'acrea',
#  'acura',
#  'ad-tramontana',
#  'adler',
#  'aiways',
#  'aixam',
#  'al-melling',
#  'aleko',
#  'alfa-romeo',
#  'alke',
#  'alpina',
#  'alpine',
#  'alvis',
#  'am-general',
#  'amc',
#  'amphicar',
#  'anaig',
#  'apal',
#  'aptera-motors',
#  'ariel',
#  'armstrong-siddeley',
#  'aro',
#  'artega',
#  'ascari',
#  'aspark',
#  'aston-martin',
#  'auburn',
#  'audi',
#  'austin',
#  'austin-healey',
#  'auto-union',
#  'autobianchi',
#  'auverland',
#  'bee-automobiles',
#  'bellier',
#  'bentley',
#  'berliet',
#  'bertone',
#  'bitter',
#  'bizzarrini',
#  'bluecar-groupe-bollore',
#  'bmw',
#  'bollore',
#  'bongarini',
#  'booxt',
#  'borgward',
#  'bowler',
#  'brabus',
#  'bremach',
#  'brilliance',
#  'bristol',
#  'brooke-cars',
#  'bugatti',
#  'buick',
#  'burby-s',
#  'byd',
#  'cadillac',
#  'caparo',
#  'carbodies',
#  'carbontech',
#  'carver',
#  'casalini',
#  'caterham',
#  'cg',
#  'chatenet',
#  'chenard-et-walcker',
#  'chery',
#  'chevrolet',
#  'china-automobile',
#  'chrysler',
#  'citroen',
#  'clenet',
#  'commuter-cars',
#  'connaught',
#  'coste',
#  'courb',
#  'cupra',
#  'curbee',
#  'dacia',
#  'daewoo',
#  'daf',
#  'daihatsu',
#  'daimler',
#  'dallara',
#  'dangel',
#  'darmont',
#  'datsun',
#  'de-fremond',
#  'de-la-chapelle',
#  'de-lorean',
#  'de-soto',
#  'de-tomaso',
#  'delage',
#  'delahaye',
#  'denza',
#  'deronda',
#  'deutsch-bonnet',
#  'devinci',
#  'devon',
#  'dfsk',
#  'dkw',
#  'dodge',
#  'dongfeng',
#  'donkervoort',
#  'donnet',
#  'dr-motor',
#  'ds',
#  'due',
#  'duesenberg',
#  'eagle',
#  'ebro',
#  'edsel',
#  'elv',
#  'embuggy',
#  'erad',
#  'estrima',
#  'exagon-motors',
#  'excalibur',
#  'facel-vega',
#  'fam-automobiles',
#  'faraday-future',
#  'faralli-&-mazzanti',
#  'farbio',
#  'ferrari',
#  'fest',
#  'fiat',
#  'fioravanti',
#  'fisker',
#  'ford',
#  'fornasari',
#  'fso',
#  'gac-gonow',
#  'gac-motor',
#  'geely',
#  'genesis',
#  'gillet',
#  'ginetta',
#  'glas',
#  'gmc',
#  'gme',
#  'goupil',
#  'grandin',
#  'great-wall',
#  'grecav',
#  'gumpert',
#  'healey',
#  'helem',
#  'hennessey',
#  'heuliez',
#  'hillman',
#  'hispano-suiza-cars',
#  'holden',
#  'hommell',
#  'honda',
#  'hopium',
#  'hotchkiss',
#  'howmet',
#  'hudson',
#  'humber',
#  'hummer',
#  'hyundai',
#  'imperial',
#  'ineos',
#  'infiniti',
#  'innocenti',
#  'innotech',
#  'intermeccanica',
#  'international',
#  'invicta',
#  'iso',
#  'isorivolta',
#  'isuzu',
#  'italcar',
#  'iveco',
#  'jaguar',
#  'jdm-simpa',
#  'jeep',
#  'jensen',
#  'jiayuan',
#  'karma',
#  'kassbohrer-setra',
#  'kia',
#  'koenigsegg',
#  'ktm',
#  'lada',
#  'lagonda',
#  'lamborghini',
#  'lancia',
#  'land-rover',
#  'landwind',
#  'lantana',
#  'laraki',
#  'ldv',
#  'leapmotor',
#  'levc',
#  'lexus',
#  'lightyear',
#  'ligier',
#  'lincoln',
#  'lister',
#  'little',
#  'lola',
#  'london-taxi-company',
#  'loremo',
#  'lotus',
#  'lucid',
#  'lumeneo',
#  'lynk-&-co',
#  'mahindra',
#  'man',
#  'marcadier',
#  'marcos',
#  'martin',
#  'marussia',
#  'maruti',
#  'maserati',
#  'matra',
#  'maxus',
#  'maybach',
#  'mazda',
#  'mclaren',
#  'mdi',
#  'mega',
#  'melkus',
#  'mercedes',
#  'mercedes-amg',
#  'mercury',
#  'messerschmitt',
#  'mev',
#  'meyers-manx',
#  'mg',
#  'mia-electric',
#  'micro',
#  'microcar',
#  'microdrive',
#  'minauto',
#  'mini',
#  'mitsubishi',
#  'mitsubishi-fuso',
#  'mitsuoka',
#  'mlt',
#  'mobilize',
#  'moke',
#  'monteverdi',
#  'morgan',
#  'morris',
#  'mosler',
#  'mpm-motors',
#  'munro',
#  'mvs',
#  'mygale',
#  'namx',
#  'nanjing',
#  'nash',
#  'neckar',
#  'newteon',
#  'newyark',
#  'nio',
#  'nissan',
#  'noble',
#  'nosmoke',
#  'noun-electric',
#  'nsu',
#  'numexia',
#  'oldsmobile',
#  'opel',
#  'ora',
#  'osi',
#  'packard',
#  'pagani',
#  'panhard',
#  'panoz',
#  'panther',
#  'pegaso',
#  'perana',
#  'peugeot',
#  'pgo',
#  'piaggio',
#  'pilbeam',
#  'pininfarina',
#  'plymouth',
#  'polestar',
#  'polski',
#  'pontiac',
#  'porsche',
#  'proton',
#  'protoscar',
#  'qoros',
#  'quant',
#  'radical',
#  'ram',
#  'rcb',
#  'realm',
#  'reliant',
#  'renault',
#  'renault-trucks',
#  'rene-bonnet',
#  'reva',
#  'reynard',
#  'riley',
#  'rimac',
#  'rinspeed',
#  'rivian',
#  'rolls-royce',
#  'ronart',
#  'rosengart',
#  'rover',
#  'russo-baltique',
#  'saab',
#  'saic',
#  'saleen',
#  'salica',
#  'salmson',
#  'samsung',
#  'santana',
#  'saturn',
#  'savel',
#  'saviem',
#  'sbarro',
#  'scania',
#  'scion',
#  'seat',
#  'secma',
#  'seres',
#  'shelby',
#  'shuanghuan',
#  'simca',
#  'singer',
#  'sivax',
#  'skoda',
#  'smart',
#  'sms',
#  'sovamag',
#  'spectre',
#  'spyker',
#  'srt',
#  'ssangyong',
#  'ssc',
#  'studebaker',
#  'stutz',
#  'subaru',
#  'sunbeam',
#  'suzuki',
#  'talbot',
#  'talbot-simca',
#  'tata',
#  'teilhol',
#  'tesla',
#  'think',
#  'toyota',
#  'trabant',
#  'triumph',
#  'tvr',
#  'ultima',
#  'umm',
#  'vaillante',
#  'van-hool',
#  'vanden-plas',
#  'vauxhall',
#  'velam',
#  'venturi',
#  'veritas',
#  'vespa',
#  'vinfast',
#  'virago',
#  'volkswagen',
#  'volteis',
#  'volvo',
#  'volvo-trucks',
#  'wallys-car',
#  'westfield',
#  'wiesmann',
#  'willys',
#  'wolseley',
#  'xev',
#  'xiaomi',
#  'xinyang',
#  'xpeng',
#  'yangwang',
#  'zagato',
#  'zap',
#  'zastava',
#  'zeekr',
#  'zenn',
#  'zenvo']

# %%
'''
# Iterate over each brand name and scrape models
for brand_name in brand_names:
    print("Scraping models for", brand_name)
    models = scrape_models(brand_name)
    print("Models for", brand_name, ":", models)
'''
# Out:
# '\n# Iterate over each brand name and scrape models\nfor brand_name in brand_names:\n    print("Scraping models for", brand_name)\n    models = scrape_models(brand_name)\n    print("Models for", brand_name, ":", models)\n'

# %%
#JSContent > section:nth-child(4) > div.main.padResponsive > div:nth-child(3) > ul > li > div.txtModeleGalerie > div > a > p'

#JSContent > section:nth-child(4) > div.main.padResponsive > div:nth-child(2) > ul > li:nth-child(1) > div.txtModeleGalerie > div > a > p

# %%
brand_names = []
for brand in df["brands"]:
    brand_names.append(brand)

# %%
brand_names
# Out:
# ['abarth',
#  'ac',
#  'acrea',
#  'acura',
#  'ad-tramontana',
#  'adler',
#  'aiways',
#  'aixam',
#  'al-melling',
#  'aleko',
#  'alfa-romeo',
#  'alke',
#  'alpina',
#  'alpine',
#  'alvis',
#  'am-general',
#  'amc',
#  'amphicar',
#  'anaig',
#  'apal',
#  'aptera-motors',
#  'ariel',
#  'armstrong-siddeley',
#  'aro',
#  'artega',
#  'ascari',
#  'aspark',
#  'aston-martin',
#  'auburn',
#  'audi',
#  'austin',
#  'austin-healey',
#  'auto-union',
#  'autobianchi',
#  'auverland',
#  'bee-automobiles',
#  'bellier',
#  'bentley',
#  'berliet',
#  'bertone',
#  'bitter',
#  'bizzarrini',
#  'bluecar-groupe-bollore',
#  'bmw',
#  'bollore',
#  'bongarini',
#  'booxt',
#  'borgward',
#  'bowler',
#  'brabus',
#  'bremach',
#  'brilliance',
#  'bristol',
#  'brooke-cars',
#  'bugatti',
#  'buick',
#  'burby-s',
#  'byd',
#  'cadillac',
#  'caparo',
#  'carbodies',
#  'carbontech',
#  'carver',
#  'casalini',
#  'caterham',
#  'cg',
#  'chatenet',
#  'chenard-et-walcker',
#  'chery',
#  'chevrolet',
#  'china-automobile',
#  'chrysler',
#  'citroen',
#  'clenet',
#  'commuter-cars',
#  'connaught',
#  'coste',
#  'courb',
#  'cupra',
#  'curbee',
#  'dacia',
#  'daewoo',
#  'daf',
#  'daihatsu',
#  'daimler',
#  'dallara',
#  'dangel',
#  'darmont',
#  'datsun',
#  'de-fremond',
#  'de-la-chapelle',
#  'de-lorean',
#  'de-soto',
#  'de-tomaso',
#  'delage',
#  'delahaye',
#  'denza',
#  'deronda',
#  'deutsch-bonnet',
#  'devinci',
#  'devon',
#  'dfsk',
#  'dkw',
#  'dodge',
#  'dongfeng',
#  'donkervoort',
#  'donnet',
#  'dr-motor',
#  'ds',
#  'due',
#  'duesenberg',
#  'eagle',
#  'ebro',
#  'edsel',
#  'elv',
#  'embuggy',
#  'erad',
#  'estrima',
#  'exagon-motors',
#  'excalibur',
#  'facel-vega',
#  'fam-automobiles',
#  'faraday-future',
#  'faralli-&-mazzanti',
#  'farbio',
#  'ferrari',
#  'fest',
#  'fiat',
#  'fioravanti',
#  'fisker',
#  'ford',
#  'fornasari',
#  'fso',
#  'gac-gonow',
#  'gac-motor',
#  'geely',
#  'genesis',
#  'gillet',
#  'ginetta',
#  'glas',
#  'gmc',
#  'gme',
#  'goupil',
#  'grandin',
#  'great-wall',
#  'grecav',
#  'gumpert',
#  'healey',
#  'helem',
#  'hennessey',
#  'heuliez',
#  'hillman',
#  'hispano-suiza-cars',
#  'holden',
#  'hommell',
#  'honda',
#  'hopium',
#  'hotchkiss',
#  'howmet',
#  'hudson',
#  'humber',
#  'hummer',
#  'hyundai',
#  'imperial',
#  'ineos',
#  'infiniti',
#  'innocenti',
#  'innotech',
#  'intermeccanica',
#  'international',
#  'invicta',
#  'iso',
#  'isorivolta',
#  'isuzu',
#  'italcar',
#  'iveco',
#  'jaguar',
#  'jdm-simpa',
#  'jeep',
#  'jensen',
#  'jiayuan',
#  'karma',
#  'kassbohrer-setra',
#  'kia',
#  'koenigsegg',
#  'ktm',
#  'lada',
#  'lagonda',
#  'lamborghini',
#  'lancia',
#  'land-rover',
#  'landwind',
#  'lantana',
#  'laraki',
#  'ldv',
#  'leapmotor',
#  'levc',
#  'lexus',
#  'lightyear',
#  'ligier',
#  'lincoln',
#  'lister',
#  'little',
#  'lola',
#  'london-taxi-company',
#  'loremo',
#  'lotus',
#  'lucid',
#  'lumeneo',
#  'lynk-&-co',
#  'mahindra',
#  'man',
#  'marcadier',
#  'marcos',
#  'martin',
#  'marussia',
#  'maruti',
#  'maserati',
#  'matra',
#  'maxus',
#  'maybach',
#  'mazda',
#  'mclaren',
#  'mdi',
#  'mega',
#  'melkus',
#  'mercedes',
#  'mercedes-amg',
#  'mercury',
#  'messerschmitt',
#  'mev',
#  'meyers-manx',
#  'mg',
#  'mia-electric',
#  'micro',
#  'microcar',
#  'microdrive',
#  'minauto',
#  'mini',
#  'mitsubishi',
#  'mitsubishi-fuso',
#  'mitsuoka',
#  'mlt',
#  'mobilize',
#  'moke',
#  'monteverdi',
#  'morgan',
#  'morris',
#  'mosler',
#  'mpm-motors',
#  'munro',
#  'mvs',
#  'mygale',
#  'namx',
#  'nanjing',
#  'nash',
#  'neckar',
#  'newteon',
#  'newyark',
#  'nio',
#  'nissan',
#  'noble',
#  'nosmoke',
#  'noun-electric',
#  'nsu',
#  'numexia',
#  'oldsmobile',
#  'opel',
#  'ora',
#  'osi',
#  'packard',
#  'pagani',
#  'panhard',
#  'panoz',
#  'panther',
#  'pegaso',
#  'perana',
#  'peugeot',
#  'pgo',
#  'piaggio',
#  'pilbeam',
#  'pininfarina',
#  'plymouth',
#  'polestar',
#  'polski',
#  'pontiac',
#  'porsche',
#  'proton',
#  'protoscar',
#  'qoros',
#  'quant',
#  'radical',
#  'ram',
#  'rcb',
#  'realm',
#  'reliant',
#  'renault',
#  'renault-trucks',
#  'rene-bonnet',
#  'reva',
#  'reynard',
#  'riley',
#  'rimac',
#  'rinspeed',
#  'rivian',
#  'rolls-royce',
#  'ronart',
#  'rosengart',
#  'rover',
#  'russo-baltique',
#  'saab',
#  'saic',
#  'saleen',
#  'salica',
#  'salmson',
#  'samsung',
#  'santana',
#  'saturn',
#  'savel',
#  'saviem',
#  'sbarro',
#  'scania',
#  'scion',
#  'seat',
#  'secma',
#  'seres',
#  'shelby',
#  'shuanghuan',
#  'simca',
#  'singer',
#  'sivax',
#  'skoda',
#  'smart',
#  'sms',
#  'sovamag',
#  'spectre',
#  'spyker',
#  'srt',
#  'ssangyong',
#  'ssc',
#  'studebaker',
#  'stutz',
#  'subaru',
#  'sunbeam',
#  'suzuki',
#  'talbot',
#  'talbot-simca',
#  'tata',
#  'teilhol',
#  'tesla',
#  'think',
#  'toyota',
#  'trabant',
#  'triumph',
#  'tvr',
#  'ultima',
#  'umm',
#  'vaillante',
#  'van-hool',
#  'vanden-plas',
#  'vauxhall',
#  'velam',
#  'venturi',
#  'veritas',
#  'vespa',
#  'vinfast',
#  'virago',
#  'volkswagen',
#  'volteis',
#  'volvo',
#  'volvo-trucks',
#  'wallys-car',
#  'westfield',
#  'wiesmann',
#  'willys',
#  'wolseley',
#  'xev',
#  'xiaomi',
#  'xinyang',
#  'xpeng',
#  'yangwang',
#  'zagato',
#  'zap',
#  'zastava',
#  'zeekr',
#  'zenn',
#  'zenvo']

# %%
'''
import requests
from bs4 import BeautifulSoup

# Function to scrape models for a given brand name
def scrape_models(brand_name):
    models = []

    # Standard URL template
    url_template = "https://www.caradisiac.com/auto--{}/modeles/"
    brand_link = url_template.format(brand_name)

    # Make a GET request to the brand link
    response = requests.get(brand_link)
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        # Find all ul elements with class "list-mod-galerie"
        ul_elements = soup.find_all("ul", class_="list-mod-galerie")
        for ul in ul_elements:
            # Find all li elements within the ul with class "col-sm-6 col-xs-12 borderBottom-xs displayGalerie"
            li_elements = ul.find_all("li", class_="col-sm-6 col-xs-12 borderBottom-xs displayGalerie")
            # Extract model names
            for li in li_elements:
                model_name = li.find("p").text.strip()
                models.append(model_name)

    return models

# List of brand names
#brand_names = ["4-stroke", "abarth", "ac", "van-hool"]

# Iterate over each brand name and scrape models
for brand_name in brand_names:
    print("Scraping models for", brand_name)
    models = scrape_models(brand_name)
    print("Models for", brand_name, ":", models)
'''
# Out:
# '\nimport requests\nfrom bs4 import BeautifulSoup\n\n# Function to scrape models for a given brand name\ndef scrape_models(brand_name):\n    models = []\n\n    # Standard URL template\n    url_template = "https://www.caradisiac.com/auto--{}/modeles/"\n    brand_link = url_template.format(brand_name)\n\n    # Make a GET request to the brand link\n    response = requests.get(brand_link)\n    if response.status_code == 200:\n        # Parse the HTML content\n        soup = BeautifulSoup(response.content, \'html.parser\')\n        # Find all ul elements with class "list-mod-galerie"\n        ul_elements = soup.find_all("ul", class_="list-mod-galerie")\n        for ul in ul_elements:\n            # Find all li elements within the ul with class "col-sm-6 col-xs-12 borderBottom-xs displayGalerie"\n            li_elements = ul.find_all("li", class_="col-sm-6 col-xs-12 borderBottom-xs displayGalerie")\n            # Extract model names\n            for li in li_elements:\n                model_name = li.find("p").text.strip()\n                models.append(model_name)\n\n    return models\n\n# List of brand names\n#brand_names = ["4-stroke", "abarth", "ac", "van-hool"]\n\n# Iterate over each brand name and scrape models\nfor brand_name in brand_names:\n    print("Scraping models for", brand_name)\n    models = scrape_models(brand_name)\n    print("Models for", brand_name, ":", models)\n'

# %%
'''
for brand_name in brand_names:
    print(scrape_models(brand_name))
'''
# Out:
# '\nfor brand_name in brand_names:\n    print(scrape_models(brand_name))\n'

# %%
'''
import requests
from bs4 import BeautifulSoup

# Function to scrape models for a given brand name
def scrape_models(brand_name):
    models = []

    # Standard URL template
    url_template = "https://www.caradisiac.com/auto--{}/modeles/"
    brand_link = url_template.format(brand_name)

    # Make a GET request to the brand link
    response = requests.get(brand_link)
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all div elements with class "txtModeleGalerie"
        div_elements = soup.find_all("div", class_="txtModeleGalerie")
        
        # Extract model names
        for div in div_elements:
            # Find the a tag inside the div
            #a_tag = div.find("a")
            #if a_tag:
                # Extract model name from p tag
                p_tag = a_tag.find("p", class_="h3")
                if p_tag:
                    model_name = p_tag.get_text(strip=True)
                    models.append(model_name)

    return models

# List of brand names obtained from the DataFrame
brand_names = df["brands"]

# Iterate over each brand name and scrape models
for brand_name in brand_names:
    print("Scraping models for", brand_name)
    models = scrape_models(brand_name)
    print("Models for", brand_name, ":", models)
'''
# Out:
# '\nimport requests\nfrom bs4 import BeautifulSoup\n\n# Function to scrape models for a given brand name\ndef scrape_models(brand_name):\n    models = []\n\n    # Standard URL template\n    url_template = "https://www.caradisiac.com/auto--{}/modeles/"\n    brand_link = url_template.format(brand_name)\n\n    # Make a GET request to the brand link\n    response = requests.get(brand_link)\n    if response.status_code == 200:\n        # Parse the HTML content\n        soup = BeautifulSoup(response.content, \'html.parser\')\n        \n        # Find all div elements with class "txtModeleGalerie"\n        div_elements = soup.find_all("div", class_="txtModeleGalerie")\n        \n        # Extract model names\n        for div in div_elements:\n            # Find the a tag inside the div\n            #a_tag = div.find("a")\n            #if a_tag:\n                # Extract model name from p tag\n                p_tag = a_tag.find("p", class_="h3")\n                if p_tag:\n                    model_name = p_tag.get_text(strip=True)\n                    models.append(model_name)\n\n    return models\n\n# List of brand names obtained from the DataFrame\nbrand_names = df["brands"]\n\n# Iterate over each brand name and scrape models\nfor brand_name in brand_names:\n    print("Scraping models for", brand_name)\n    models = scrape_models(brand_name)\n    print("Models for", brand_name, ":", models)\n'

# %%
import requests
from bs4 import BeautifulSoup

# Function to scrape models for a given brand name
def scrape_models(brand_name):
    models = []

    # Standard URL template
    url_template = "https://www.caradisiac.com/auto--{}/modeles/"
    brand_link = url_template.format(brand_name)

    # Make a GET request to the brand link
    response = requests.get(brand_link)
    if response.status_code == 200:
        # Print out the HTML content for debugging
        #print(response.content)
        
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all a elements with class "txtModeleGalerie"
        a_elements = soup.select('.txtModeleGalerie a')
        
        # Extract model names from href and title attributes
        for a in a_elements:
            model_name = a.get('title', '').strip()
            if model_name:
                models.append(model_name)
    else:
        print("Failed to fetch:", response.status_code)

    return models

# List of brand names obtained from the DataFrame
brand_names = df["brands"]

# Iterate over each brand name and scrape models
for brand_name in brand_names:
    print("Scraping models for", brand_name)
    models = scrape_models(brand_name)
    #df["models"] = models
    print("Models for", brand_name, ":", models)
# Out:
# Scraping models for abarth
# Models for abarth : ['Abarth 500', 'Abarth 600e', 'Abarth 124', 'Abarth Grande Punto', 'Abarth Punto Evo', 'Abarth Scorpion']
# Scraping models for ac
# Models for ac : ['Ac 428', 'Ac Cobra', 'Ac Coupe Aceca', 'Ac Greyhound', 'Ac Mkvi', 'Ac Roadster Ace', 'Ac Shelby Cobra']
# Scraping models for acrea
# Models for acrea : ['Acrea Zest']
# Scraping models for acura
# Models for acura : ['Acura Mdx']
# Scraping models for ad-tramontana
# Models for ad-tramontana : ['Ad Tramontana Tramontana']
# Scraping models for adler
# Models for adler : ['Adler Diplomat', 'Adler Primus', 'Adler Trumpf']
# Scraping models for aiways
# Models for aiways : ['Aiways U6', 'Aiways U5']
# Scraping models for aixam
# Models for aixam : ['Aixam City', 'Aixam Coupe', 'Aixam Crossline', 'Aixam Crossover', 'Aixam D-truck', 'Aixam E City', 'Aixam E Coupe', 'Aixam E Crossover', 'Aixam E-scouty', 'Aixam E-truck', 'Aixam Gto', 'Aixam Minauto', 'Aixam 300', 'Aixam 400', 'Aixam 500', 'Aixam A540', 'Aixam A721', 'Aixam A741', 'Aixam A751', 'Aixam E-worker', 'Aixam Roadline', 'Aixam Scouty']
# Scraping models for al-melling
# Models for al-melling : []
# Scraping models for aleko
# Models for aleko : ['Aleko Aleko']
# Scraping models for alfa-romeo
# Models for alfa-romeo : ['Alfa Romeo 33 Stradale', 'Alfa Romeo Giulia', 'Alfa Romeo Stelvio', 'Alfa Romeo Tonale', 'Alfa Romeo 1300', 'Alfa Romeo 145', 'Alfa Romeo 146', 'Alfa Romeo 147', 'Alfa Romeo 155', 'Alfa Romeo 156', 'Alfa Romeo 159', 'Alfa Romeo 1600', 'Alfa Romeo 164', 'Alfa Romeo 166', 'Alfa Romeo 1750', 'Alfa Romeo 1900', 'Alfa Romeo 2000', 'Alfa Romeo 2600', 'Alfa Romeo 33', 'Alfa Romeo 4c', 'Alfa Romeo 6', 'Alfa Romeo 75', 'Alfa Romeo 8c', 'Alfa Romeo 90', 'Alfa Romeo Alfasud', 'Alfa Romeo Alfetta', 'Alfa Romeo Berlina', 'Alfa Romeo Brera', 'Alfa Romeo Duetto', 'Alfa Romeo Giulietta', 'Alfa Romeo Gt', 'Alfa Romeo Gtv', 'Alfa Romeo Mito', 'Alfa Romeo Montreal', 'Alfa Romeo Rz', 'Alfa Romeo Spider', 'Alfa Romeo Sud', 'Alfa Romeo Sz Es30', 'Alfa Romeo Gloria Concept', 'Alfa Romeo Kamal', 'Alfa Romeo Tonale Concept']
# Scraping models for alke
# Models for alke : ['Alke Atx']
# Scraping models for alpina
# Models for alpina : ['Alpina B3', 'Alpina B4', 'Alpina B5', 'Alpina B6', 'Alpina B7', 'Alpina B8', 'Alpina D4', 'Alpina D5', 'Alpina Xb7', 'Alpina Xd3', 'Alpina B10', 'Alpina B11', 'Alpina B12', 'Alpina B9', 'Alpina D10', 'Alpina D3']
# Scraping models for alpine
# Failed to fetch: 404
# Models for alpine : []
# Scraping models for alvis
# Models for alvis : ['Alvis Cabriolet', 'Alvis Coach']
# Scraping models for am-general
# Models for am-general : ['Am General Hmmwv']
# Scraping models for amc
# Models for amc : ['Amc Ambassador', 'Amc American', 'Amc Amx', 'Amc Classic', 'Amc Concord', 'Amc Custom', 'Amc Eagle', 'Amc Gremlin', 'Amc Hornet', 'Amc Javelin', 'Amc Marlin', 'Amc Matador', 'Amc Pacer', 'Amc Rambler', 'Amc Rebel', 'Amc Spirit']
# Scraping models for amphicar
# Models for amphicar : ['Amphicar 770']
# Scraping models for anaig
# Models for anaig : ['Anaig Light']
# Scraping models for apal
# Models for apal : ['Apal Coupe']
# Scraping models for aptera-motors
# Models for aptera-motors : []
# Scraping models for ariel
# Models for ariel : ['Ariel Atom']
# Scraping models for armstrong-siddeley
# Models for armstrong-siddeley : ['Armstrong Siddeley Sapphire', 'Armstrong Siddeley Star Sapphire']
# Scraping models for aro
# Models for aro : ['Aro 10', 'Aro 10.0', 'Aro 10.1', 'Aro 10.4', 'Aro 10.5', 'Aro 244', 'Aro Cross Lander', 'Aro Forester', 'Aro Spartana', 'Aro Trapeurs']
# Scraping models for artega
# Models for artega : ['Artega Gt']
# Scraping models for ascari
# Models for ascari : []
# Scraping models for aspark
# Models for aspark : ['Aspark Owl']
# Scraping models for aston-martin
# Models for aston-martin : ['Aston Martin Vanquish 3', 'Aston Martin Db11', 'Aston Martin Db12', 'Aston Martin Dbs', 'Aston Martin Dbx', 'Aston Martin V12 Vantage', 'Aston Martin Valkyrie', 'Aston Martin Vanquish', 'Aston Martin Vantage', 'Aston Martin Vantage Gt8', 'Aston Martin Cygnet', 'Aston Martin Db2', 'Aston Martin Db4', 'Aston Martin Db5', 'Aston Martin Db6', 'Aston Martin Db7', 'Aston Martin Db9', 'Aston Martin Lagonda', 'Aston Martin One-77', 'Aston Martin Rapide', 'Aston Martin V8', 'Aston Martin V8 Vantage', 'Aston Martin Virage', 'Aston Martin Zagato', 'Aston Martin Dbx Concept', 'Aston Martin Lagonda Concept', 'Aston Martin V12 Zagato', 'Aston Martin Vulcan']
# Scraping models for auburn
# Models for auburn : ['Auburn 851']
# Scraping models for audi
# Models for audi : ['Audi A1', 'Audi A3', 'Audi A4', 'Audi A4 Allroad', 'Audi A5', 'Audi A6', 'Audi A6 Allroad', 'Audi A7', 'Audi A8', 'Audi E-tron', 'Audi E-tron Gt', 'Audi E-tron S', 'Audi E-tron S Sportback', 'Audi E-tron Sportback', 'Audi Q2', 'Audi Q3', 'Audi Q4', 'Audi Q5', 'Audi Q6 E-tron', 'Audi Q7', 'Audi Q8', 'Audi R8', 'Audi Rs E-tron Gt', 'Audi Rs Q3', 'Audi Rs Q8', 'Audi Rs3', 'Audi Rs4', 'Audi Rs5', 'Audi Rs6', 'Audi Rs7', 'Audi S3', 'Audi S4', 'Audi S5', 'Audi S6', 'Audi S7', 'Audi S8', 'Audi Sq2', 'Audi Sq5', 'Audi Sq7', 'Audi Sq8', 'Audi Tt', 'Audi Tt Rs', 'Audi Tts', 'Audi 100', 'Audi 200', 'Audi 50', 'Audi 60', 'Audi 70', 'Audi 75', 'Audi 80', 'Audi 90', 'Audi 920', 'Audi A2', 'Audi Allroad', 'Audi Coupe', 'Audi Coupe Gt', 'Audi Quattro', 'Audi Rs2', 'Audi S1', 'Audi S2', 'Audi V8', 'Audi A1 Sportback Concept', 'Audi A2 Concept', 'Audi A3 Concept', 'Audi Activshpere Concept', 'Audi Ai Trail', 'Audi Crosslane Coupe Concept', 'Audi E-tron Quattro Concept', 'Audi E-tron Sportback Concept', 'Audi E-tron Spyder', 'Audi Le Mans', 'Audi Nuvolari', 'Audi P18 E-tron Concept', 'Audi Prologue Concept', 'Audi Quattro Concept', 'Audi R8 Tdi Le Mans Concept', 'Audi Tt Quattro Sport Concept', 'Audi Tt Sportback Concept', 'Audi Urban Concept']
# Scraping models for austin
# Models for austin : ['Austin 1000', 'Austin 1100', 'Austin 1275', 'Austin 1300', 'Austin 1800', 'Austin 2200', 'Austin Allegro', 'Austin Maestro', 'Austin Marina', 'Austin Maxi', 'Austin Metro', 'Austin Mini', 'Austin Mini-moke', 'Austin Minor', 'Austin Montego', 'Austin Princess', 'Austin Seven', 'Austin Taxi Cab']
# Scraping models for austin-healey
# Models for austin-healey : ['Austin Healey 100', 'Austin Healey 3000', 'Austin Healey Sprite']
# Scraping models for auto-union
# Models for auto-union : ['Auto Union 1000', 'Auto Union Jeep', 'Auto Union Junior']
# Scraping models for autobianchi
# Models for autobianchi : ['Autobianchi 500', 'Autobianchi A111', 'Autobianchi A112', 'Autobianchi Bianchina', 'Autobianchi Lutece', 'Autobianchi Primula', 'Autobianchi Stellina', 'Autobianchi Y10']
# Scraping models for auverland
# Models for auverland : ['Auverland A3', 'Auverland A4']
# Scraping models for bee-automobiles
# Models for bee-automobiles : []
# Scraping models for bellier
# Models for bellier : ['Bellier B8', 'Bellier Divane', 'Bellier Docker', 'Bellier Jade', 'Bellier Opale', 'Bellier Voiturette']
# Scraping models for bentley
# Models for bentley : ['Bentley Bentayga', 'Bentley Continental', 'Bentley Flying Spur', 'Bentley Mulsanne', 'Bentley Arnage', 'Bentley Azure', 'Bentley Brooklands', 'Bentley Corniche', 'Bentley Eight', 'Bentley Mark', 'Bentley S1', 'Bentley S2', 'Bentley S3', 'Bentley Silver Cloud', 'Bentley T', 'Bentley Turbo R', 'Bentley Turbo Rt', 'Bentley Type R', 'Bentley Exp 10 Speed 6 Concept', 'Bentley Exp 9 F']
# Scraping models for berliet
# Models for berliet : ['Berliet 944', 'Berliet Dauphine']
# Scraping models for bertone
# Models for bertone : ['Bertone Freeclimber', 'Bertone Suagna']
# Scraping models for bitter
# Models for bitter : ['Bitter Diplomat']
# Scraping models for bizzarrini
# Models for bizzarrini : ['Bizzarrini Gt']
# Scraping models for bluecar-groupe-bollore
# Models for bluecar-groupe-bollore : ['Bluecar Groupe Bollore Blueutility']
# Scraping models for bmw
# Models for bmw : ['Bmw I3', 'Bmw I4', 'Bmw I5', 'Bmw I7', 'Bmw I8', 'Bmw Ix', 'bmw Ix1', 'Bmw Ix2', 'Bmw Ix3', 'Bmw Serie 1', 'Bmw Serie 2', 'Bmw Serie 3', 'Bmw Serie 4', 'Bmw Serie 5', 'Bmw Serie 6', 'Bmw Serie 7', 'Bmw Serie 8', 'Bmw Serie 8 Gran Coupe', 'Bmw X1', 'Bmw X2', 'Bmw X3', 'Bmw X4', 'Bmw X5', 'Bmw X6', 'Bmw X7', 'Bmw Xm', 'Bmw Z4', 'Bmw 1500', 'Bmw 1600', 'Bmw 1800', 'Bmw 1802', 'Bmw 2.5', 'Bmw 2.8', 'Bmw 2000', 'Bmw 2002', 'Bmw 2500', 'Bmw 2800', 'Bmw 3.0', 'Bmw 3.3', 'Bmw 3200', 'Bmw 501', 'Bmw 502', 'Bmw 503', 'Bmw 507', 'Bmw 600', 'Bmw 700', 'Bmw I3s', 'Bmw M1', 'Bmw Serie 3 Gt', 'Bmw Serie 5 Gt', 'Bmw Z1', 'Bmw Z3', 'Bmw Z8', 'Bmw Concept 4', 'Bmw Concept Active E', 'Bmw Concept Active Tourer', 'Bmw Concept Z4', 'Bmw Efficientdynamics', 'Bmw I Vision Circular', 'Bmw I100 Coupe Activehybrid', 'Bmw I3 Concept', 'Bmw I8 Concept', 'Bmw Ix3 Concept', 'Bmw M Vision Next Concept', 'Bmw Serie 5 Gt Concept', 'Bmw Serie 6 Coupe Concept', 'Bmw Vision Connecteddrive', 'Bmw X1 Concept', 'Bmw Xm Concept']
# Scraping models for bollore
# Models for bollore : ['Bollore Bluecar', 'Bollore Bluesummer', 'Bollore Blueutility', 'Bollore Blue Car Concept']
# Scraping models for bongarini
# Models for bongarini : []
# Scraping models for booxt
# Models for booxt : ['Booxt Dynotruck']
# Scraping models for borgward
# Models for borgward : ['Borgward 2300', 'Borgward Arabella', 'Borgward Hansa', 'Borgward Isabella']
# Scraping models for bowler
# Models for bowler : []
# Scraping models for brabus
# Models for brabus : []
# Scraping models for bremach
# Models for bremach : ['Bremach Job Xtreme']
# Scraping models for brilliance
# Models for brilliance : ['Brilliance Bc3', 'Brilliance Bs2', 'Brilliance Bs4', 'Brilliance Bs6']
# Scraping models for bristol
# Models for bristol : ['Bristol 400', 'Bristol 401', 'Bristol 402', 'Bristol 404', 'Bristol 405', 'Bristol 406', 'Bristol 407', 'Bristol 408', 'Bristol 409', 'Bristol 411', 'Bristol 412']
# Scraping models for brooke-cars
# Models for brooke-cars : []
# Scraping models for bugatti
# Models for bugatti : ['Bugatti Chiron', 'Bugatti Eb110', 'Bugatti Type 35', 'Bugatti Type 41', 'Bugatti Type 46', 'Bugatti Type 57', 'Bugatti Veyron', 'Bugatti Divo']
# Scraping models for buick
# Models for buick : ['Buick Century', 'Buick Coupe', 'Buick Electra', 'Buick Gran Sport', 'Buick Gs 350', 'Buick Gs 400', 'Buick Invicta', 'Buick Le Sabre', 'Buick Limited', 'Buick Park Avenue', 'Buick Regal', 'Buick Riviera', 'Buick Roadmaster', 'Buick Skyhawk', 'Buick Skylark', 'Buick Special', 'Buick Super', 'Buick Wildcat', 'Buick Verano']
# Scraping models for burby-s
# Models for burby-s : ['Burby S E-moke']
# Scraping models for byd
# Models for byd : ['Byd Dolphin', 'Byd Etp3', 'Byd Seal', 'Byd Seal U', 'Byd Atto 3', 'Byd Han', 'Byd Tang']
# Scraping models for cadillac
# Models for cadillac : ['Cadillac Ats', 'Cadillac Ct6', 'Cadillac Escalade', 'Cadillac 75 Limousine', 'Cadillac Allante', 'Cadillac Bls', 'Cadillac Brougham', 'Cadillac Calais', 'Cadillac Coupe', 'Cadillac Coupe Deville', 'Cadillac Coupe Eldorado', 'Cadillac Cts', 'Cadillac Cts-v', 'Cadillac Deville', 'Cadillac Dts', 'Cadillac Eldorado', 'Cadillac Fleetwood', 'Cadillac Serie 62', 'Cadillac Serie 70', 'Cadillac Serie 75', 'Cadillac Seville', 'Cadillac Sixty', 'Cadillac Srx', 'Cadillac Sts', 'Cadillac Xlr', 'Cadillac Xt4', 'Cadillac Xt5', 'Cadillac Ciel Concept', 'Cadillac Cien', 'Cadillac Cts Concept', 'Cadillac Elmiraj Concept', 'Cadillac Provoq', 'Cadillac Sixteen', 'Cadillac Vizion', 'Cadillac Elr', 'Cadillac Optiq']
# Scraping models for caparo
# Models for caparo : []
# Scraping models for carbodies
# Models for carbodies : ['Carbodies Fx4', 'Carbodies Taxi Hire', 'Carbodies Tx4']
# Scraping models for carbontech
# Models for carbontech : []
# Scraping models for carver
# Models for carver : ['Carver One']
# Scraping models for casalini
# Models for casalini : ['Casalini 550 Alpina', 'Casalini 550 Gransport', 'Casalini 550 Granturismo', 'Casalini 550 Trofeo', 'Casalini M20', 'Casalini Twist+', 'Casalini Diva', 'Casalini Kerry', 'Casalini M10', 'Casalini M14', 'Casalini Pickup', 'Casalini Sulky', 'Casalini Wrs']
# Scraping models for caterham
# Models for caterham : ['Caterham Seven', 'Caterham Super Seven']
# Scraping models for cg
# Models for cg : ['Cg Coupe', 'Cg Spider']
# Scraping models for chatenet
# Models for chatenet : ['Chatenet Ch 26', 'Chatenet Ch 30', 'Chatenet Ch 32', 'Chatenet Ch 40', 'Chatenet Ch 46', 'Chatenet Sporteevo', 'Chatenet Baroodeur', 'Chatenet Media', 'Chatenet Speedino']
# Scraping models for chenard-et-walcker
# Models for chenard-et-walcker : ['Chenard Et Walcker Aiglon']
# Scraping models for chery
# Models for chery : []
# Scraping models for chevrolet
# Models for chevrolet : ['Chevrolet Camaro', 'Chevrolet Corvette', 'Chevrolet 3100', 'Chevrolet Alero', 'Chevrolet Apache', 'Chevrolet Avalanche', 'Chevrolet Aveo', 'Chevrolet Bel Air', 'Chevrolet Beretta', 'Chevrolet Biscayne', 'Chevrolet Blazer', 'Chevrolet C10', 'Chevrolet C20', 'Chevrolet C30', 'Chevrolet Caprice', 'Chevrolet Captiva', 'Chevrolet Chevelle', 'Chevrolet Chevy', 'Chevrolet Citation', 'Chevrolet Corsica', 'Chevrolet Corvair', 'Chevrolet Cruze', 'Chevrolet El Camino', 'Chevrolet Epica', 'Chevrolet Equinox', 'Chevrolet Evanda', 'Chevrolet Fleetline', 'Chevrolet Hhr', 'Chevrolet Impala', 'Chevrolet K10 Pick Up', 'Chevrolet K5 Blazer', 'Chevrolet Kalos', 'Chevrolet Lacetti', 'Chevrolet Malibu', 'Chevrolet Matiz', 'Chevrolet Monte Carlo', 'Chevrolet Monza', 'Chevrolet Nova', 'Chevrolet Nubira', 'Chevrolet Orlando', 'Chevrolet Rezzo', 'Chevrolet S10 Pick Up', 'Chevrolet Silverado', 'Chevrolet Spark', 'Chevrolet Sport Van', 'Chevrolet Ssr', 'Chevrolet Suburban', 'Chevrolet Tahoe', 'Chevrolet Trailblazer', 'Chevrolet Trans Sport', 'Chevrolet Trax', 'Chevrolet Van Express', 'Chevrolet Vega', 'Chevrolet Volt', 'Chevrolet Beat', 'Chevrolet Colorado Rallye', 'Chevrolet Groove', 'Chevrolet Matiz M3x', 'Chevrolet Miray Concept', 'Chevrolet Orlando Concept', 'Chevrolet S3x', 'Chevrolet Sequel', 'Chevrolet Spark Concept', 'Chevrolet Trax Concept', 'Chevrolet Volt Concept', 'Chevrolet Wtcc Ultra Concept', 'Chevrolet Bolt', 'Chevrolet Sonic']
# Scraping models for china-automobile
# Models for china-automobile : ['China Automobile Chika', 'China Automobile Kiff']
# Scraping models for chrysler
# Models for chrysler : ['Chrysler Aspen', 'Chrysler 160', 'Chrysler 200 C', 'Chrysler 2l', 'Chrysler 300 B', 'Chrysler 300 C', 'Chrysler 300 M', 'Chrysler Crossfire', 'Chrysler Es', 'Chrysler Grand Voyager', 'Chrysler Imperial', 'Chrysler Lebaron', 'Chrysler Neon', 'Chrysler New Yorker', 'Chrysler Newport', 'Chrysler Pacifica', 'Chrysler Prowler', 'Chrysler Pt Cruiser', 'Chrysler Saratoga', 'Chrysler Sebring', 'Chrysler Stratus', 'Chrysler Town &amp; Country', 'Chrysler Viper', 'Chrysler Vision', 'Chrysler Voyager', 'Chrysler Windsor', 'Chrysler 200c Ev', 'Chrysler 700c Concept', 'Chrysler Airflite', 'Chrysler Eco Voyager']
# Scraping models for citroen
# Models for citroen : ['Citroen Ami', 'Citroen Berlingo', 'Citroen C3', 'Citroen C3 Aircross', 'Citroen C4', 'Citroen C5 Aircross', 'Citroen C5 X', 'Citroen Grand C4 Spacetourer', 'Citroen Jumper', 'Citroen Jumpy', 'Citroen Spacetourer', 'Citroen 2cv', 'Citroen Ac4', 'Citroen Acadiane', 'Citroen Ax', 'Citroen Axel', 'Citroen B14', 'Citroen B2', 'Citroen Burton', 'Citroen Bx', 'Citroen C-crosser', 'Citroen C-elysee', 'Citroen C-zero', 'Citroen C1', 'Citroen C15', 'Citroen C2', 'Citroen C25', 'Citroen C3 Picasso', 'Citroen C3 Pluriel', 'Citroen C35', 'Citroen C4 Aircross', 'Citroen C4 Cactus', 'Citroen C4 Picasso', 'Citroen C4 Spacetourer', 'Citroen C5', 'Citroen C6', 'Citroen C8', 'Citroen Cx', 'Citroen D', 'Citroen Ds', 'Citroen Ds3', 'Citroen Ds4', 'Citroen Ds5', 'Citroen Dyane', 'Citroen E-mehari', 'Citroen Evasion', 'Citroen Grand C4 Picasso', 'Citroen Gs', 'Citroen Gsa', 'Citroen Id', 'Citroen Ln', 'Citroen Lna', 'Citroen Mehari', 'Citroen Nemo', 'Citroen Picasso', 'Citroen Saxo', 'Citroen Sm', 'Citroen Traction', 'Citroen Type C', 'Citroen Type H', 'Citroen Visa', 'Citroen Xantia', 'Citroen Xm', 'Citroen Xsara', 'Citroen Zx', 'Citroen 19-19 Concept', 'Citroen Aircross Concept', 'Citroen Ami One Concept', 'Citroen C-aircross Concept', 'Citroen C-airdream', 'Citroen C-airlounge', 'Citroen C-airplay', 'Citroen C-buggy', 'Citroen C-cactus', 'Citroen C-crosser Concept', 'Citroen C-metisse', 'Citroen C-sportlounge', 'Citroen C1 Urban Ride Concept', 'Citroen C4 Cactus Airflow Concept', 'Citroen C4 Hdi Hybride Concept', 'Citroen C5 Airscape', 'Citroen Cactus', 'Citroen Cactus M Concept', 'Citroen Concept 9', 'Citroen Cruise Crosser', 'Citroen Cxperience Concept', 'Citroen Ds Inside', 'Citroen Ds4 R Concept', 'Citroen Gt Concept', 'Citroen Hypnos', 'Citroen Lacoste', 'Citroen Metropolis', 'Citroen Osmose', 'Citroen Revolte', 'Citroen Spacetourer Hyphen Concept', 'Citroen Survolt', 'Citroen Technospace Concept', 'Citroen Tubik']
# Scraping models for clenet
# Models for clenet : ['Clenet Serie 1', 'Clenet Serie 2']
# Scraping models for commuter-cars
# Models for commuter-cars : []
# Scraping models for connaught
# Models for connaught : []
# Scraping models for coste
# Models for coste : ['Coste C1']
# Scraping models for courb
# Models for courb : ['Courb C-zen']
# Scraping models for cupra
# Models for cupra : ['Cupra Ateca', 'Cupra Born', 'Cupra Formentor', 'Cupra Leon', 'Cupra Raval', 'Cupra Tavascan', 'Cupra Formentor Concept', 'Cupra Tavascan Concept', 'Cupra Urban Rebel Concept']
# Scraping models for curbee
# Failed to fetch: 404
# Models for curbee : []
# Scraping models for dacia
# Models for dacia : ['Dacia Bigster', 'Dacia Duster', 'Dacia Jogger', 'Dacia Logan', 'Dacia Sandero', 'Dacia Spring', 'Dacia Dokker', 'Dacia Lodgy', 'Dacia Bigster Concept', 'Dacia Duster Concept']
# Scraping models for daewoo
# Models for daewoo : ['Daewoo Espero', 'Daewoo Evanda', 'Daewoo Kalos', 'Daewoo Korando', 'Daewoo Lacetti', 'Daewoo Lanos', 'Daewoo Leganza', 'Daewoo Matiz', 'Daewoo Musso', 'Daewoo Nexia', 'Daewoo Nubira', 'Daewoo Rexton', 'Daewoo Rezzo', 'Daewoo Flex', 'Daewoo Scope', 'Daewoo Vada']
# Scraping models for daf
# Models for daf : ['Daf 1600', 'Daf 2700', 'Daf 2800', 'Daf 33', 'Daf 3600', 'Daf 44', 'Daf 45', 'Daf 46', 'Daf 55', 'Daf 65', 'Daf 66', 'Daf 75', 'Daf 800', 'Daf 85', 'Daf 95 Ati', 'Daf 95 Xf', 'Daf Cf 85', 'Daf Lf', 'Daf N Torpedo', 'Daf Xf 105', 'Daf Xf 95']
# Scraping models for daihatsu
# Models for daihatsu : ['Daihatsu Applause', 'Daihatsu Charade', 'Daihatsu Copen', 'Daihatsu Cuore', 'Daihatsu Domino', 'Daihatsu Feroza', 'Daihatsu Gran Move', 'Daihatsu Hijet', 'Daihatsu Materia', 'Daihatsu Move', 'Daihatsu Rocky', 'Daihatsu Rocky Wagon', 'Daihatsu Sirion', 'Daihatsu Terios', 'Daihatsu Trevis', 'Daihatsu Yrv', 'Daihatsu D-bone', 'Daihatsu D-compact X-over', 'Daihatsu Hvs', 'Daihatsu Mud-master', 'Daihatsu Ufe 3', 'Daihatsu Xl-c', 'Daihatsu Tanto Custom']
# Scraping models for daimler
# Models for daimler : ['Daimler 250', 'Daimler Conquest', 'Daimler Df', 'Daimler Double Six', 'Daimler Majestic Major', 'Daimler Saloon', 'Daimler Sovereign', 'Daimler Sp 250', 'Daimler V8']
# Scraping models for dallara
# Models for dallara : ['Dallara Stradale']
# Scraping models for dangel
# Models for dangel : ['Dangel Berlingo', 'Dangel 504', 'Dangel 505', 'Dangel Boxer', 'Dangel Ducato', 'Dangel Expert', 'Dangel Jumper', 'Dangel Jumpy', 'Dangel Partner', 'Dangel Partner Tepee', 'Dangel Scudo']
# Scraping models for darmont
# Models for darmont : ['Darmont Cabriolet', 'Darmont V']
# Scraping models for datsun
# Models for datsun : ['Datsun Fairlady', 'Datsun 100', 'Datsun 120', 'Datsun 160', 'Datsun 220', 'Datsun 260z', 'Datsun 280', 'Datsun Cedric', 'Datsun Coupe', 'Datsun Laurel', 'Datsun Violet']
# Scraping models for de-fremond
# Models for de-fremond : ['De Fremond Fargo']
# Scraping models for de-la-chapelle
# Models for de-la-chapelle : ['De La Chapelle 57', 'De La Chapelle Roadster', 'De La Chapelle Type 55']
# Scraping models for de-lorean
# Models for de-lorean : ['De Lorean Dmc-12']
# Scraping models for de-soto
# Models for de-soto : ['De Soto Adventurer', 'De Soto Coupe', 'De Soto Custom', 'De Soto Deluxe', 'De Soto Diplomat', 'De Soto Firedome', 'De Soto Fireflite', 'De Soto Firesweep', 'De Soto Power Master']
# Scraping models for de-tomaso
# Models for de-tomaso : ['De Tomaso Deauville', 'De Tomaso Guara', 'De Tomaso Lonchamps', 'De Tomaso Mangusta', 'De Tomaso Pantera']
# Scraping models for delage
# Models for delage : ['Delage Berline', 'Delage Coach', 'Delage Limousine']
# Scraping models for delahaye
# Models for delahaye : ['Delahaye Berline', 'Delahaye Coach', 'Delahaye Limousine', 'Delahaye Vlr']
# Scraping models for denza
# Failed to fetch: 404
# Models for denza : []
# Scraping models for deronda
# Models for deronda : []
# Scraping models for deutsch-bonnet
# Models for deutsch-bonnet : ['Deutsch-bonnet Hbr5']
# Scraping models for devinci
# Models for devinci : ['Devinci Db 718', 'Devinci Db 719', 'Devinci Db 721']
# Scraping models for devon
# Models for devon : []
# Scraping models for dfsk
# Models for dfsk : ['Dfsk Ecocity 35', 'Dfsk Ecocity 35 Combi']
# Scraping models for dkw
# Models for dkw : ['Dkw 1000', 'Dkw F']
# Scraping models for dodge
# Models for dodge : ['Dodge Challenger', 'Dodge Charger', 'Dodge Ram', 'Dodge Avenger', 'Dodge Caliber', 'Dodge Coronet', 'Dodge D100', 'Dodge D24', 'Dodge Dakota', 'Dodge Dart', 'Dodge Durango', 'Dodge Journey', 'Dodge Kingsway', 'Dodge Lancer', 'Dodge Magnum', 'Dodge Matador', 'Dodge Monaco', 'Dodge Nitro', 'Dodge Omni', 'Dodge Phoenix', 'Dodge Pioneer', 'Dodge Polara', 'Dodge Ramcharger', 'Dodge Royal', 'Dodge Royal Custom', 'Dodge Stealth', 'Dodge Viper', 'Dodge Wayfarer', 'Dodge Demon Concept', 'Dodge Envi', 'Dodge Zeo']
# Scraping models for dongfeng
# Models for dongfeng : []
# Scraping models for donkervoort
# Models for donkervoort : ['Donkervoort D8', 'Donkervoort S8', 'Donkervoort S8at']
# Scraping models for donnet
# Models for donnet : ['Donnet Berline', 'Donnet Coupe', 'Donnet Limousine']
# Scraping models for dr-motor
# Models for dr-motor : []
# Scraping models for ds
# Models for ds : ['Ds Ds 4', 'Ds Ds 7', 'Ds Ds 9', 'Ds Ds3', 'Ds Ds 3', 'Ds Ds 3 Crossback', 'Ds Ds 4 Crossback', 'Ds Ds 5', 'Ds Ds 7 Crossback', 'Ds Divine Ds Concept', 'Ds E-tense Concept', 'Ds X E-tense Concept', 'Ds 5ls', 'Ds 6wr']
# Scraping models for due
# Models for due : ['Due First', 'Due First Luxe']
# Scraping models for duesenberg
# Models for duesenberg : []
# Scraping models for eagle
# Models for eagle : ['Eagle Tallon']
# Scraping models for ebro
# Models for ebro : ['Ebro Patrol']
# Scraping models for edsel
# Models for edsel : ['Edsel Corsair', 'Edsel Pacer', 'Edsel Ranger', 'Edsel Villager']
# Scraping models for elv
# Models for elv : ['Elv Simplycity']
# Scraping models for embuggy
# Models for embuggy : ['Embuggy Vintage']
# Scraping models for erad
# Models for erad : ['Erad Voiturette']
# Scraping models for estrima
# Models for estrima : ['Estrima Biro']
# Scraping models for exagon-motors
# Models for exagon-motors : []
# Scraping models for excalibur
# Models for excalibur : ['Excalibur 35x', 'Excalibur Phaeton', 'Excalibur Serie 1', 'Excalibur Serie 2', 'Excalibur Serie 3', 'Excalibur Serie 4', 'Excalibur Serie 5', 'Excalibur Ss', 'Excalibur Ssk']
# Scraping models for facel-vega
# Models for facel-vega : ['Facel Vega Excellence', 'Facel Vega Facel', 'Facel Vega Facel 6', 'Facel Vega Facel Ii', 'Facel Vega Facellia', 'Facel Vega Fv', 'Facel Vega Hk 500']
# Scraping models for fam-automobiles
# Models for fam-automobiles : ['Fam Automobiles Sprity', 'Fam Automobiles F-city']
# Scraping models for faraday-future
# Models for faraday-future : ['Faraday Future Ff 91']
# Scraping models for faralli-&-mazzanti
# Failed to fetch: 410
# Models for faralli-&-mazzanti : []
# Scraping models for farbio
# Models for farbio : []
# Scraping models for ferrari
# Models for ferrari : ['Ferrari 296', 'Ferrari 488', 'Ferrari 812', 'Ferrari 812 Gts', 'Ferrari Daytona Sp3', 'Ferrari F8 Tributo', 'Ferrari Laferrari', 'Ferrari Portofino', 'Ferrari Purosangue', 'Ferrari Roma', 'Ferrari Sf90 Spider', 'Ferrari Sf90 Stradale', 'Ferrari 208', 'Ferrari 212', 'Ferrari 250', 'Ferrari 275', 'Ferrari 288', 'Ferrari 308', 'Ferrari 328', 'Ferrari 330', 'Ferrari 348', 'Ferrari 360', 'Ferrari 365', 'Ferrari 400', 'Ferrari 412', 'Ferrari 456', 'Ferrari 458', 'Ferrari 512', 'Ferrari 512 Bb', 'Ferrari 550', 'Ferrari 575', 'Ferrari 599', 'Ferrari 612', 'Ferrari California', 'Ferrari Dino', 'Ferrari Enzo', 'Ferrari F12', 'Ferrari F150', 'Ferrari F355', 'Ferrari F40', 'Ferrari F430', 'Ferrari F50', 'Ferrari Ff', 'Ferrari Fxx', 'Ferrari Gtc4lusso', 'Ferrari Mondial', 'Ferrari Monza', 'Ferrari Spider 365', 'Ferrari Testarossa']
# Scraping models for fest
# Failed to fetch: 404
# Models for fest : []
# Scraping models for fiat
# Models for fiat : ['Fiat 500', 'Fiat 500 L', 'Fiat 500 X', 'Fiat 600', 'Fiat Doblo Cargo', 'Fiat Ducato', 'Fiat Fiorino', 'Fiat Panda', 'Fiat Punto', 'Fiat Scudo', 'Fiat Talento', 'Fiat Tipo', 'Fiat Topolino', 'Fiat Ulysse', 'Fiat 1100', 'Fiat 1200', 'Fiat 124', 'Fiat 126', 'Fiat 127', 'Fiat 128', 'Fiat 130', 'Fiat 1300', 'Fiat 131', 'Fiat 132', 'Fiat 1400', 'Fiat 1500', 'Fiat 1600', 'Fiat 1800', 'Fiat 1900', 'Fiat 2100', 'Fiat 2300', 'Fiat 508', 'Fiat 850', 'Fiat Argenta', 'Fiat Barchetta', 'Fiat Brava', 'Fiat Bravo', 'Fiat Cinquecento', 'Fiat Coupe', 'Fiat Croma', 'Fiat Dino', 'Fiat Doblo', 'Fiat Freemont', 'Fiat Fullback', 'Fiat Grande Punto', 'Fiat Idea', 'Fiat Marea', 'Fiat Multipla', 'Fiat Palio', 'Fiat Punto Evo', 'Fiat Qubo', 'Fiat Regata', 'Fiat Ritmo', 'Fiat Sedici', 'Fiat Seicento', 'Fiat Spider', 'Fiat Stilo', 'Fiat Strada', 'Fiat Tempra', 'Fiat Uno', 'Fiat X1/9', 'Fiat 500 Concept', 'Fiat Ducato Truckster Concept', 'Fiat Panda Aria Concept']
# Scraping models for fioravanti
# Models for fioravanti : []
# Scraping models for fisker
# Models for fisker : ['Fisker Pear', 'Fisker Alaska', 'Fisker Ocean', 'Fisker Ronin', 'Fisker Karma', 'Fisker Atlantic']
# Scraping models for ford
# Models for ford : ['Ford Bronco', 'Ford Ecosport', 'Ford Expedition', 'Ford Explorer', 'Ford F150', 'Ford Fiesta', 'Ford Focus', 'Ford Galaxy', 'Ford Gt', 'Ford Ka', 'Ford Kuga', 'Ford Maverick', 'Ford Mercury', 'Ford Mustang', 'Ford Mustang Mach-e', 'Ford Puma', 'Ford Ranger', 'Ford S-max', 'Ford Tourneo', 'Ford Tourneo Connect', 'Ford Tourneo Courier', 'Ford Tourneo Custom', 'Ford Transit', 'Ford Transit Connect', 'Ford Transit Courier', 'Ford Transit Custom', 'Ford 12 M', 'Ford 15 M', 'Ford 17 M', 'Ford 20 M', 'Ford 26 M', 'Ford 33', 'Ford A', 'Ford Aerostar', 'Ford Anglia', 'Ford B', 'Ford B-max', 'Ford C-max', 'Ford Capri', 'Ford Cobra', 'Ford Comete', 'Ford Compact Driver', 'Ford Consul', 'Ford Corsair', 'Ford Cortina', 'Ford Cougar', 'Ford Country', 'Ford Courrier', 'Ford Crestline', 'Ford Custom', 'Ford Econoline', 'Ford Edge', 'Ford Escort', 'Ford F100', 'Ford F250', 'Ford F350', 'Ford Fairlane', 'Ford Fairline', 'Ford Falcon', 'Ford Flex', 'Ford Focus C-max', 'Ford Fusion', 'Ford Galaxie', 'Ford Granada', 'Ford Grand C-max', 'Ford Grand Torino', 'Ford Grand Tourneo Connect', 'Ford Gt 40', 'Ford Ka+', 'Ford Lincoln', 'Ford Ltd', 'Ford Mainline', 'Ford Mondeo', 'Ford Orion', 'Ford Pinto', 'Ford Probe', 'Ford Ranchero', 'Ford Rs200', 'Ford Scorpio', 'Ford Sierra', 'Ford T', 'Ford Taunus', 'Ford Thunderbird', 'Ford Torino', 'Ford Vedette', 'Ford Vendome', 'Ford Zephyr', 'Ford Edge Concept', 'Ford Evos Concept', 'Ford Fcv', 'Ford Iosis', 'Ford Iosis Max', 'Ford Iosis X', 'Ford S-max Concept', 'Ford Visos']
# Scraping models for fornasari
# Models for fornasari : ['Fornasari Rr450', 'Fornasari Rr600']
# Scraping models for fso
# Models for fso : ['Fso Atou', 'Fso Caro']
# Scraping models for gac-gonow
# Models for gac-gonow : ['Gac Gonow Ga200', 'Gac Gonow Ga500', 'Gac Gonow Way']
# Scraping models for gac-motor
# Models for gac-motor : ['Gac Motor Gs5']
# Scraping models for geely
# Models for geely : []
# Scraping models for genesis
# Models for genesis : ['Genesis Gv60', 'Genesis G90']
# Scraping models for gillet
# Models for gillet : ['Gillet Vertigo']
# Scraping models for ginetta
# Models for ginetta : ['Ginetta G33', 'Ginetta G50']
# Scraping models for glas
# Models for glas : ['Glas 1300', 'Glas 1700', 'Glas 2600', 'Glas 3000']
# Scraping models for gmc
# Models for gmc : ['Gmc Savana', 'Gmc Sierra Pick-up', 'Gmc 2500', 'Gmc Acadia', 'Gmc Canyon', 'Gmc Denali', 'Gmc Sierra', 'Gmc Sle', 'Gmc Sonoma', 'Gmc Yukon', 'Gmc Hummer']
# Scraping models for gme
# Models for gme : ['Gme Midi', 'Gme Minibus', 'Gme Rascal']
# Scraping models for goupil
# Models for goupil : ['Goupil G3']
# Scraping models for grandin
# Models for grandin : ['Grandin Dallas', 'Grandin Torpedo']
# Scraping models for great-wall
# Models for great-wall : []
# Scraping models for grecav
# Models for grecav : ['Grecav Sonique', 'Grecav Eke', 'Grecav Epuc']
# Scraping models for gumpert
# Models for gumpert : ['Gumpert Apollo', 'Gumpert Tornante']
# Scraping models for healey
# Models for healey : []
# Scraping models for helem
# Models for helem : []
# Scraping models for hennessey
# Models for hennessey : ['Hennessey Venom F5']
# Scraping models for heuliez
# Models for heuliez : ['Heuliez Cellulo', 'Heuliez Macarena']
# Scraping models for hillman
# Models for hillman : ['Hillman Husky', 'Hillman Imp', 'Hillman Minx', 'Hillman Super Minx']
# Scraping models for hispano-suiza-cars
# Models for hispano-suiza-cars : ['Hispano Suiza Cars Carmen']
# Scraping models for holden
# Models for holden : []
# Scraping models for hommell
# Models for hommell : ['Hommell Barquette', 'Hommell Berlinette']
# Scraping models for honda
# Models for honda : ['Honda Accord', 'Honda Civic', 'Honda Cr-v', 'Honda E', 'Honda Hr-v', 'Honda Jazz', 'Honda Zr-v', 'Honda Acty', 'Honda Concerto', 'Honda Cr-z', 'Honda Crx', 'Honda Ev', 'Honda Fr-v', 'Honda Insight', 'Honda Integra', 'Honda Legend', 'Honda Logo', 'Honda N400', 'Honda N600', 'Honda Nsx', 'Honda Prelude', 'Honda Quintet', 'Honda Ridgeline', 'Honda S2000', 'Honda S600', 'Honda S800', 'Honda Shuttle', 'Honda Stream', 'Honda Z600', 'Honda Accord Tourer Concept', 'Honda Civic Hybrid Sports Concept', 'Honda Civic Type R Concept', 'Honda Civic Type R Prototype', 'Honda Civic Wagon Concept', 'Honda Cr-v Prototype', 'Honda Cr-z Concept', 'Honda E-prototype Concept', 'Honda Ev-ster', 'Honda Fcv', 'Honda Fcx Concept', 'Honda Hsc', 'Honda Imas', 'Honda Insight 2 Concept', 'Honda Nsx Concept', 'Honda Small Hybrid Sports', 'Honda E:ny1', 'Honda Fcx Clarity', 'Honda S660']
# Scraping models for hopium
# Models for hopium : ['Hopium Machina Vision']
# Scraping models for hotchkiss
# Models for hotchkiss : ['Hotchkiss 617', 'Hotchkiss Am 80', 'Hotchkiss Jeep']
# Scraping models for howmet
# Models for howmet : []
# Scraping models for hudson
# Models for hudson : ['Hudson Commodore', 'Hudson Coupe', 'Hudson Hornet', 'Hudson Italia', 'Hudson Metropolitan', 'Hudson Pacemaker', 'Hudson Super Six', 'Hudson Wasp']
# Scraping models for humber
# Models for humber : ['Humber Hawk', 'Humber Imperial', 'Humber Pullman', 'Humber Sceptre', 'Humber Super Snipe']
# Scraping models for hummer
# Models for hummer : ['Hummer H Ev', 'Hummer H1', 'Hummer H2', 'Hummer H3', 'Hummer Hx', 'Hummer Transformers']
# Scraping models for hyundai
# Models for hyundai : ['Hyundai Bayon', 'Hyundai I10', 'Hyundai I20', 'Hyundai I30', 'Hyundai Ioniq 5', 'Hyundai Ioniq 6', 'Hyundai Ioniq 7', 'Hyundai Kona', 'Hyundai Nexo', 'Hyundai Santa Fe', 'Hyundai Tucson', 'Hyundai Accent', 'Hyundai Atos', 'Hyundai Atos Prime', 'Hyundai Azera', 'Hyundai Coupe', 'Hyundai Elantra', 'Hyundai Galloper', 'Hyundai Genesis', 'Hyundai Getz', 'Hyundai Grand Santa Fe', 'Hyundai H 100', 'Hyundai H1 Van', 'Hyundai I40', 'Hyundai Ioniq', 'Hyundai Ix20', 'Hyundai Ix35', 'Hyundai Ix55', 'Hyundai Lantra', 'Hyundai Matrix', 'Hyundai Pony', 'Hyundai Satellite', 'Hyundai Scoupe', 'Hyundai Sonata', 'Hyundai Terracan', 'Hyundai Trajet', 'Hyundai Veloster', 'Hyundai Xg', 'Hyundai Arnejs', 'Hyundai Ccs', 'Hyundai Clix', 'Hyundai Concept 45', 'Hyundai Curb Concept', 'Hyundai E3', 'Hyundai Euro', 'Hyundai Hcd-1', 'Hyundai Hcd-2', 'Hyundai Hcd-3', 'Hyundai Hcd-5', 'Hyundai Hcd-6', 'Hyundai Hcd-7', 'Hyundai Hcd-8', 'Hyundai Hed-1', 'Hyundai I-blue', 'Hyundai I-mode', 'Hyundai I.oniq Concept', 'Hyundai Ix-onic', 'Hyundai Neos', 'Hyundai Neos 2', 'Hyundai Olv', 'Hyundai Portico', 'Hyundai Santa Cruz Crossover Truck Concept', 'Hyundai Veloster Concept', 'Hyundai Equus']
# Scraping models for imperial
# Models for imperial : ['Imperial Crown', 'Imperial Lebaron']
# Scraping models for ineos
# Models for ineos : ['Ineos Fusilier', 'Ineos Grenadier']
# Scraping models for infiniti
# Models for infiniti : ['Infiniti Ex', 'Infiniti Fx', 'Infiniti G', 'Infiniti M', 'Infiniti Q30', 'Infiniti Q50', 'Infiniti Q60', 'Infiniti Q70', 'Infiniti Qx30', 'Infiniti Qx50', 'Infiniti Qx56', 'Infiniti Qx70', 'Infiniti Emerg-e', 'Infiniti Etherea Concept', 'Infiniti Le Concept', 'Infiniti Performance Line G Cabrio Concept', 'Infiniti Q30 Concept', 'Infiniti Qx30 Concept', 'Infiniti Jx']
# Scraping models for innocenti
# Models for innocenti : ['Innocenti 1100', 'Innocenti 120', 'Innocenti 500', 'Innocenti 650', 'Innocenti 90', 'Innocenti 950', 'Innocenti 990', 'Innocenti Mini']
# Scraping models for innotech
# Models for innotech : []
# Scraping models for intermeccanica
# Models for intermeccanica : ['Intermeccanica Gt Apollo', 'Intermeccanica Indra', 'Intermeccanica Italia', 'Intermeccanica Roadster', 'Intermeccanica Speedster', 'Intermeccanica Squire']
# Scraping models for international
# Models for international : ['International Berline', 'International Coupe', 'International Wagonette']
# Scraping models for invicta
# Models for invicta : []
# Scraping models for iso
# Models for iso : ['Iso Fidia', 'Iso Grifo', 'Iso Lele', 'Iso Rivolta']
# Scraping models for isorivolta
# Models for isorivolta : []
# Scraping models for isuzu
# Models for isuzu : ['Isuzu D-max', 'Isuzu M 21', 'Isuzu M 27', 'Isuzu Serie N', 'Isuzu Trooper']
# Scraping models for italcar
# Models for italcar : ['Italcar T2', 'Italcar T3']
# Scraping models for iveco
# Models for iveco : ['Iveco Daily', 'Iveco Stralis', 'Iveco Daily Chassis Cab', 'Iveco Daily Van', 'Iveco Eurocargo', 'Iveco Massif', 'Iveco Minicab', 'Iveco Minivan']
# Scraping models for jaguar
# Models for jaguar : ['Jaguar E-pace', 'Jaguar F-pace', 'Jaguar F-type', 'Jaguar I-pace', 'Jaguar Xe', 'Jaguar Xf', 'Jaguar 2.4', 'Jaguar 240', 'Jaguar 3.4', 'Jaguar 3.8', 'Jaguar 340', 'Jaguar 420', 'Jaguar Coupe Xk', 'Jaguar Daimler', 'Jaguar Mk Ii', 'Jaguar Mk Iv', 'Jaguar Mk Viii', 'Jaguar Mk X', 'Jaguar Roadster Xk', 'Jaguar S-type', 'Jaguar Ss', 'Jaguar Type C', 'Jaguar Type E', 'Jaguar X-type', 'Jaguar Xj', 'Jaguar Xj12', 'Jaguar Xj220', 'Jaguar Xj6', 'Jaguar Xj8', 'Jaguar Xjr', 'Jaguar Xjr-s', 'Jaguar Xjs', 'Jaguar Xjs-c', 'Jaguar Xk', 'Jaguar Xk8', 'Jaguar Xkr', 'Jaguar Xkss', 'Jaguar C-x16 Concept', 'Jaguar C-x17 Concept', 'Jaguar C-xf', 'Jaguar Cx-75', 'Jaguar I-pace Concept', 'Jaguar Lightweight Coupe Concept', 'Jaguar R-d6', 'Jaguar R-type Coupe']
# Scraping models for jdm-simpa
# Models for jdm-simpa : ['Jdm Simpa Aloes', 'Jdm Simpa Max Ut', 'Jdm Simpa Roxsy', 'Jdm Simpa Titane', 'Jdm Simpa Xheos', 'Jdm Simpa Abaca', 'Jdm Simpa Albizia', 'Jdm Simpa Orane']
# Scraping models for jeep
# Models for jeep : ['Jeep Avenger', 'Jeep Cj5', 'Jeep Compass', 'Jeep Gladiator', 'Jeep Grand Cherokee', 'Jeep Renegade', 'Jeep Wrangler', 'Jeep Cherokee', 'Jeep Cj7', 'Jeep Comanche', 'Jeep Commander', 'Jeep Ford', 'Jeep Grand Wagoneer', 'Jeep Jeepster', 'Jeep Patriot', 'Jeep Wagoneer', 'Jeep Willys', 'Jeep Compass Concept', 'Jeep Renegade Concept']
# Scraping models for jensen
# Models for jensen : ['Jensen 541', 'Jensen C-v8', 'Jensen Healey', 'Jensen Interceptor']
# Scraping models for jiayuan
# Models for jiayuan : ['Jiayuan City Cargo', 'Jiayuan City Fun', 'Jiayuan City Van']
# Scraping models for karma
# Models for karma : ['Karma Revero']
# Scraping models for kassbohrer-setra
# Models for kassbohrer-setra : ['Kassbohrer Setra 215']
# Scraping models for kia
# Models for kia : ['Kia Ceed', 'Kia Ev5', 'Kia Ev6', 'Kia Ev9', 'Kia Niro', 'Kia Picanto', 'Kia Proceed', 'Kia Rio', 'Kia Sorento', 'Kia Soul', 'Kia Sportage', 'Kia Stinger', 'Kia Stonic', 'Kia Xceed', 'Kia Besta', 'Kia Carens', 'Kia Carnival', 'Kia Cee D', 'Kia Cerato', 'Kia Clarus', 'Kia E-niro', 'Kia E-soul', 'Kia K2500', 'Kia K2700', 'Kia K2900', 'Kia Magentis', 'Kia Opirus', 'Kia Optima', 'Kia Pregio', 'Kia Pride', 'Kia Pro Cee D', 'Kia Rocsta', 'Kia Sephia', 'Kia Shuma', 'Kia Venga', 'Kia Cee D Hybrid Concept', 'Kia Cerato Concept', 'Kia Ev5 Concept', 'Kia Gt', 'Kia Kcd-1 Slice', 'Kia Kcv7 Concept', 'Kia Multi-s Concept', 'Kia Niro Concept', 'Kia No.3', 'Kia Pop', 'Kia Pro Cee D Concept', 'Kia Pro Cee&#039;d Concept 2', 'Kia Provo', 'Kia Sportage Fcev Concept']
# Scraping models for koenigsegg
# Models for koenigsegg : ['Koenigsegg Regera', 'Koenigsegg Agera', 'Koenigsegg Cc 8s', 'Koenigsegg Cc R']
# Scraping models for ktm
# Models for ktm : ['Ktm X-bow']
# Scraping models for lada
# Models for lada : ['Lada Vesta', 'Lada Xray', 'Lada 110', 'Lada 111', 'Lada 112', 'Lada 2104', 'Lada 2105', 'Lada 2107', 'Lada 4x4', 'Lada Kalina', 'Lada Kalinka', 'Lada Natacha', 'Lada Niva', 'Lada Priora', 'Lada Sagona', 'Lada Samara', 'Lada C', 'Lada C-cross', 'Lada Revolution 3', 'Lada Granta']
# Scraping models for lagonda
# Models for lagonda : ['Lagonda 3 L', 'Lagonda Rapide']
# Scraping models for lamborghini
# Models for lamborghini : ['Lamborghini Aventador', 'Lamborghini Centenario', 'Lamborghini Huracan', 'Lamborghini Revuelto', 'Lamborghini Sian', 'Lamborghini Urus', 'Lamborghini 350', 'Lamborghini 350 Gt', 'Lamborghini 3500', 'Lamborghini 400', 'Lamborghini 400 Gt', 'Lamborghini Countach', 'Lamborghini Diablo', 'Lamborghini Espada', 'Lamborghini Gallardo', 'Lamborghini Islero', 'Lamborghini Jalpa', 'Lamborghini Jarama', 'Lamborghini Lm', 'Lamborghini Miura', 'Lamborghini Murcielago', 'Lamborghini Reventon', 'Lamborghini Silhouette', 'Lamborghini Urraco', 'Lamborghini Veneno', 'Lamborghini Asterion Concept', 'Lamborghini Estoque Concept', 'Lamborghini Sesto Elemento']
# Scraping models for lancia
# Models for lancia : ['Lancia Ypsilon', 'Lancia 2000', 'Lancia Appia', 'Lancia Aurelia', 'Lancia Beta', 'Lancia Coupe', 'Lancia Dedra', 'Lancia Delta', 'Lancia Flaminia', 'Lancia Flavia', 'Lancia Fulvia', 'Lancia Gamma', 'Lancia Kappa', 'Lancia Lybra', 'Lancia Montecarlo', 'Lancia Musa', 'Lancia Phedra', 'Lancia Prisma', 'Lancia Stratos', 'Lancia Thema', 'Lancia Thesis', 'Lancia Trevi', 'Lancia Voyager', 'Lancia Y10', 'Lancia Zeta', 'Lancia Compact Mpv', 'Lancia Delta Hpe Concept', 'Lancia Flavia Cabrio Concept', 'Lancia Flavia Concept', 'Lancia Fulvia Concept', 'Lancia Grand Voyager']
# Scraping models for land-rover
# Models for land-rover : ['Land Rover Defender', 'Land Rover Discovery', 'Land Rover Discovery Sport', 'Land Rover Range Rover', 'Land Rover Range Rover Evoque', 'Land Rover Range Rover Sport', 'Land Rover Range Rover Velar', 'Land Rover Freelander', 'Land Rover Land', 'Land Rover Moke', 'Land Rover Dc100', 'Land Rover Dc100 Sport', 'Land Rover Range Rover Evoque Convertible Concept']
# Scraping models for landwind
# Models for landwind : ['Landwind Fashion', 'Landwind X-pedition', 'Landwind X7']
# Scraping models for lantana
# Models for lantana : ['Lantana Buggy']
# Scraping models for laraki
# Models for laraki : ['Laraki Fulgura']
# Scraping models for ldv
# Models for ldv : ['Ldv Maxus']
# Scraping models for leapmotor
# Models for leapmotor : ['Leapmotor T03']
# Scraping models for levc
# Models for levc : ['Levc Tx', 'Levc Vn5']
# Scraping models for lexus
# Models for lexus : ['Lexus Es', 'Lexus Lbx', 'Lexus Lc', 'Lexus Lm', 'Lexus Ls', 'Lexus Nx', 'Lexus Rc', 'Lexus Rx', 'Lexus Rz', 'Lexus Ux', 'Lexus Ct', 'Lexus Gs', 'Lexus Is', 'Lexus Lfa', 'Lexus Lx', 'Lexus Sc', 'Lexus Lc Convertible Concept', 'Lexus Lf-a Concept Coupe', 'Lexus Lf-a Concept Roadster', 'Lexus Lf-c Concept', 'Lexus Lf-lc Concept', 'Lexus Lf-nx', 'Lexus Lf-s Concept', 'Lexus Lf-sa Concept', 'Lexus Lf-xh Concept']
# Scraping models for lightyear
# Models for lightyear : ['Lightyear Lightyear 0']
# Scraping models for ligier
# Models for ligier : ['Ligier Be', 'Ligier Ixo', 'Ligier Js', 'Ligier Js50', 'Ligier Js50l', 'Ligier Myli', 'Ligier Optimax', 'Ligier Pulse 4', 'Ligier X-too Rs', 'Ligier Ambra', 'Ligier Nova', 'Ligier Nova 500', 'Ligier Prima', 'Ligier X-pro', 'Ligier X-too', 'Ligier X-too Ii', 'Ligier X-too Max', 'Ligier X-too R', 'Ligier X-too S']
# Scraping models for lincoln
# Models for lincoln : ['Lincoln Aviator', 'Lincoln Capri', 'Lincoln Continental', 'Lincoln Mark Lt', 'Lincoln Mark Viii', 'Lincoln Navigator', 'Lincoln Premiere', 'Lincoln Town Car', 'Lincoln Mkc', 'Lincoln Mks', 'Lincoln Mkt', 'Lincoln Mkx', 'Lincoln Mkz']
# Scraping models for lister
# Models for lister : []
# Scraping models for little
# Models for little : []
# Scraping models for lola
# Models for lola : []
# Scraping models for london-taxi-company
# Models for london-taxi-company : ['London Taxi Company Tx4']
# Scraping models for loremo
# Models for loremo : []
# Scraping models for lotus
# Models for lotus : ['Lotus Emeya', 'Lotus 3-eleven', 'Lotus Eletre', 'Lotus Elise', 'Lotus Elite', 'Lotus Emira', 'Lotus Evora', 'Lotus Exige', 'Lotus 2 Eleven', 'Lotus 340 R', 'Lotus Eclat', 'Lotus Elan', 'Lotus Eleven', 'Lotus Esprit', 'Lotus Europa', 'Lotus Excel', 'Lotus Seven']
# Scraping models for lucid
# Models for lucid : ['Lucid Air']
# Scraping models for lumeneo
# Models for lumeneo : ['Lumeneo Neoma', 'Lumeneo Smera']
# Scraping models for lynk-&-co
# Failed to fetch: 410
# Models for lynk-&-co : []
# Scraping models for mahindra
# Models for mahindra : ['Mahindra Bolero', 'Mahindra Cj', 'Mahindra Goa']
# Scraping models for man
# Models for man : ['Man Tge', 'Man 19.262', 'Man Hydrodrive', 'Man Lion S Coach', 'Man Tgl', 'Man Tgm', 'Man Tgs', 'Man Tgx']
# Scraping models for marcadier
# Models for marcadier : ['Marcadier Barzoi', 'Marcadier Canam']
# Scraping models for marcos
# Models for marcos : ['Marcos 1500', 'Marcos 1600', 'Marcos 1800 Gt', 'Marcos 2 Litres', 'Marcos 3 Litres', 'Marcos Mantis', 'Marcos Mantula', 'Marcos Mini Marcos', 'Marcos Ugly Duckling']
# Scraping models for martin
# Models for martin : ['Martin Ac Cobra', 'Martin Seven']
# Scraping models for marussia
# Models for marussia : []
# Scraping models for maruti
# Models for maruti : ['Maruti 800']
# Scraping models for maserati
# Models for maserati : ['Maserati Ghibli', 'Maserati Granturismo', 'Maserati Grecale', 'Maserati Levante', 'Maserati Mc20', 'Maserati Quattroporte', 'Maserati 2.24v', 'Maserati 222', 'Maserati 228', 'Maserati 3200 Gt', 'Maserati 3500 Gt', 'Maserati 3500 Gti', 'Maserati 420', 'Maserati 422', 'Maserati 424 V', 'Maserati 425', 'Maserati 430', 'Maserati 5000 Gt', 'Maserati Biturbo', 'Maserati Bora', 'Maserati Coupe', 'Maserati Grancabrio', 'Maserati Gransport', 'Maserati Indy', 'Maserati Karif', 'Maserati Khamsin', 'Maserati Kyalami', 'Maserati Mc12', 'Maserati Merak', 'Maserati Mexico', 'Maserati Mistral', 'Maserati Sebring', 'Maserati Shamal', 'Maserati Spyder', 'Maserati Alfieri', 'Maserati Kubang Concept']
# Scraping models for matra
# Models for matra : ['Matra Bagheera', 'Matra Djet', 'Matra Gem', 'Matra Jet', 'Matra M530', 'Matra Murena', 'Matra Rancho']
# Scraping models for maxus
# Failed to fetch: 404
# Models for maxus : []
# Scraping models for maybach
# Models for maybach : ['Maybach 57 Berline', 'Maybach 62 Berline']
# Scraping models for mazda
# Models for mazda : ['Mazda 2', 'Mazda 3', 'Mazda Cx-5', 'Mazda Cx-60', 'Mazda Cx-80', 'Mazda Mx-30', 'Mazda Mx5', 'Mazda 121', 'Mazda 323', 'Mazda 5', 'Mazda 6', 'Mazda 626', 'Mazda 929', 'Mazda B2500', 'Mazda Bt-50', 'Mazda Cosmo', 'Mazda Cx-3', 'Mazda Cx-7', 'Mazda Cx-9', 'Mazda Demio', 'Mazda E 2000', 'Mazda E 2200', 'Mazda Mpv', 'Mazda Mx3', 'Mazda Mx6', 'Mazda Premacy', 'Mazda Rx-7', 'Mazda Rx-8', 'Mazda Tribute', 'Mazda Xedos 6', 'Mazda Xedos 9', 'Mazda 1', 'Mazda 1 Concept', 'Mazda Cx-5 Concept', 'Mazda Hakaze Concept', 'Mazda Hazumi Concept', 'Mazda Kiyora', 'Mazda Kusabi', 'Mazda Minagi Concept', 'Mazda Mx-crossport', 'Mazda Mx-flexa', 'Mazda Mx-micro', 'Mazda Mx-sport-tourer', 'Mazda Mx-sportif', 'Mazda Rx-evolv', 'Mazda Sassou', 'Mazda Senku', 'Mazda Takeri Concept', 'Mazda Cx-30']
# Scraping models for mclaren
# Models for mclaren : ['Mclaren 540c', 'Mclaren 570gt', 'Mclaren 570s', 'Mclaren 600 Lt', 'Mclaren 620r', 'Mclaren 675 Lt', 'Mclaren 720s', 'Mclaren 750 S', 'Mclaren 765lt', 'Mclaren Artura', 'Mclaren Elva', 'Mclaren Gt', 'Mclaren 650 S', 'Mclaren F1', 'Mclaren Mp4-12c', 'Mclaren P1', 'Mclaren P1 Concept', 'Mclaren Senna']
# Scraping models for mdi
# Models for mdi : []
# Scraping models for mega
# Models for mega : ['Mega Club', 'Mega Concept', 'Mega Fourgon 400', 'Mega Multitruck', 'Mega Plateau Ridelles', 'Mega Track']
# Scraping models for melkus
# Models for melkus : []
# Scraping models for mercedes
# Models for mercedes : ['Mercedes 709', 'Mercedes Antos', 'Mercedes Atego', 'Mercedes Citan', 'Mercedes Cla', 'Mercedes Classe A', 'Mercedes Classe B', 'Mercedes Classe C', 'Mercedes Classe Cls', 'Mercedes Classe E', 'Mercedes Classe G', 'Mercedes Classe S', 'Mercedes Classe T', 'Mercedes Classe V', 'Mercedes Classe X', 'Mercedes Cle', 'Mercedes Eqa', 'Mercedes Eqb', 'Mercedes Eqe', 'Mercedes Eqs', 'Mercedes Eqs Suv', 'Mercedes Eqt', 'Mercedes Eqv', 'Mercedes Gla', 'Mercedes Glb', 'Mercedes Glc', 'Mercedes Glc Coupe', 'Mercedes Gle', 'Mercedes Gle Coupe', 'Mercedes Gls', 'Mercedes Marco Polo', 'Mercedes Sl', 'Mercedes Slc', 'Mercedes Sprinter', 'Mercedes Vito', 'Mercedes 1017', 'Mercedes 170', 'Mercedes 180', 'Mercedes 190', 'Mercedes 200', 'Mercedes 220', 'Mercedes 230', 'Mercedes 240', 'Mercedes 250', 'Mercedes 260', 'Mercedes 280', 'Mercedes 300', 'Mercedes 319', 'Mercedes 320', 'Mercedes 350', 'Mercedes 380', 'Mercedes 400', 'Mercedes 408', 'Mercedes 420', 'Mercedes 450', 'Mercedes 500', 'Mercedes 508', 'Mercedes 560', 'Mercedes 600', 'Mercedes Actros', 'Mercedes Axor', 'Mercedes Cl', 'Mercedes Classe Clc', 'Mercedes Classe Gl', 'Mercedes Classe Glk', 'Mercedes Classe M', 'Mercedes Classe R', 'Mercedes Clk', 'Mercedes Gamme T1', 'Mercedes Slk', 'Mercedes Slr', 'Mercedes Sls', 'Mercedes Unimog', 'Mercedes Vaneo', 'Mercedes Viano', 'Mercedes Classe A Necar', 'Mercedes Classe B Electric Concept', 'Mercedes Clk Shooting Brake', 'Mercedes Eqt Concept', 'Mercedes F700', 'Mercedes Fascination Concept', 'Mercedes Sports Tourer Vision B', 'Mercedes Sports Tourer Vision R', 'Mercedes Vision Cls', 'Mercedes Vision Eq Silver Arrow', 'Mercedes Vision Mercedes-maybach 6', 'Mercedes Eqc']
# Scraping models for mercedes-amg
# Models for mercedes-amg : ['Mercedes-amg Gt', 'Mercedes-amg One', 'Mercedes-amg Project One', 'Mercedes-amg Sl', 'Mercedes-amg Vision Amg Concept']
# Scraping models for mercury
# Models for mercury : ['Mercury Colony Park', 'Mercury Comet', 'Mercury Cougar', 'Mercury Custom', 'Mercury Cyclone', 'Mercury M100', 'Mercury Montclair', 'Mercury Montego', 'Mercury Monterey', 'Mercury Park Lane', 'Mercury Turnpike Cruiser', 'Mercury Villager']
# Scraping models for messerschmitt
# Models for messerschmitt : ['Messerschmitt Kr']
# Scraping models for mev
# Models for mev : ['Mev Daytona', 'Mev Hummer', 'Mev Zip']
# Scraping models for meyers-manx
# Models for meyers-manx : ['Meyers Manx Manx']
# Scraping models for mg
# Models for mg : ['Mg Cyberster', 'Mg Marvel R', 'Mg Mg Ehs', 'Mg Mg Zs', 'Mg Mg3', 'Mg Mg5', 'Mg 1100', 'Mg 1300', 'Mg A', 'Mg B', 'Mg C', 'Mg F', 'Mg M-type', 'Mg Midget', 'Mg Montego', 'Mg Rv8', 'Mg Tc', 'Mg Td', 'Mg Tf', 'Mg X-power', 'Mg Zr', 'Mg Zs', 'Mg Zt', 'Mg Cyberster Concept', 'Mg 3', 'Mg 6', 'Mg Mg4']
# Scraping models for mia-electric
# Models for mia-electric : ['Mia Electric Mia']
# Scraping models for micro
# Failed to fetch: 404
# Models for micro : []
# Scraping models for microcar
# Models for microcar : ['Microcar Due', 'Microcar Due5', 'Microcar Due6', 'Microcar M-pro', 'Microcar M.cross', 'Microcar M.go', 'Microcar Mc Cargo', 'Microcar Mgo5', 'Microcar Lyra', 'Microcar M8', 'Microcar Mc1', 'Microcar Mc2', 'Microcar Mc2.2', 'Microcar Virgo']
# Scraping models for microdrive
# Failed to fetch: 404
# Models for microdrive : []
# Scraping models for minauto
# Models for minauto : ['Minauto Cross', 'Minauto Cross Gt', 'Minauto Eco', 'Minauto Gt']
# Scraping models for mini
# ...
# Scraping models for ronart
# Models for ronart : []
# Scraping models for rosengart
# Models for rosengart : ['Rosengart Lr2', 'Rosengart Lr4', 'Rosengart Lr44']
# Scraping models for rover
# Models for rover : ['Rover 25', 'Rover 45', 'Rover 75', 'Rover Maestro', 'Rover Mini', 'Rover Montego', 'Rover P4', 'Rover P5', 'Rover P6', 'Rover Sd1', 'Rover Serie 100', 'Rover Serie 200', 'Rover Serie 400', 'Rover Serie 600', 'Rover Serie 800', 'Rover Streetwise']
# Scraping models for russo-baltique
# Models for russo-baltique : ['Russo-baltique Impression']
# Scraping models for saab
# Models for saab : ['Saab 9-3', 'Saab 9-3x', 'Saab 9-4x', 'Saab 9-5', 'Saab 9-7 X', 'Saab 900', 'Saab 9000', 'Saab 92', 'Saab 93', 'Saab 95', 'Saab 96', 'Saab 99', 'Saab Gt', 'Saab Monte Carlo', 'Saab Sonett', 'Saab 9-3 Concept', 'Saab 9-3 Sport-hatch Concept', 'Saab 9-3x Concept', 'Saab 9-4x Biopower Concept', 'Saab 9-5 Concept', 'Saab 9-x Air', 'Saab 9-x Biohybrid Concept', 'Saab 9-x Convertible Concept', 'Saab Aero-x']
# Scraping models for saic
# Models for saic : ['Saic Maxus']
# Scraping models for saleen
# Models for saleen : ['Saleen S7']
# Scraping models for salica
# Models for salica : []
# Scraping models for salmson
# Models for salmson : ['Salmson 2300 S', 'Salmson La Randonnee']
# Scraping models for samsung
# Models for samsung : ['Samsung Sm7']
# Scraping models for santana
# Models for santana : ['Santana Ps10', 'Santana S300', 'Santana S350', 'Santana S410', 'Santana S413', 'Santana Samurai', 'Santana Vitara']
# Scraping models for saturn
# Models for saturn : []
# Scraping models for savel
# Models for savel : ['Savel Voiturette']
# Scraping models for saviem
# Models for saviem : ['Saviem Sg2']
# Scraping models for sbarro
# Models for sbarro : ['Sbarro Jumpy Atlante Des Neiges']
# Scraping models for scania
# Models for scania : ['Scania 124', 'Scania 93']
# Scraping models for scion
# Models for scion : ['Scion Fr-s']
# Scraping models for seat
# Models for seat : ['Seat Arona', 'Seat Ateca', 'Seat Ibiza', 'Seat Leon', 'Seat Tarraco', 'Seat 124', 'Seat 127', 'Seat 128', 'Seat 132', 'Seat 133', 'Seat 600', 'Seat 850', 'Seat Alhambra', 'Seat Altea', 'Seat Altea Freetrack', 'Seat Arosa', 'Seat Cordoba', 'Seat Exeo', 'Seat Fura', 'Seat Inca', 'Seat Malaga', 'Seat Marbella', 'Seat Mii', 'Seat Ronda', 'Seat Terra', 'Seat Toledo', 'Seat 20v20 Concept', 'Seat Altea Freetrack Concept', 'Seat El-born Concept', 'Seat Ginebra', 'Seat Ibe', 'Seat Tango', 'Seat Tribu']
# Scraping models for secma
# Models for secma : ['Secma F-16', 'Secma F 440', 'Secma Fun', 'Secma Fun Extr M', 'Secma Fun Tech', 'Secma Fun Runner Concept']
# Scraping models for seres
# Models for seres : ['Seres Dfsk Ec 35', 'Seres Seres 3']
# Scraping models for shelby
# Models for shelby : ['Shelby Cobra 289', 'Shelby Cobra 427', 'Shelby Cobra Daytona', 'Shelby Gt 500']
# Scraping models for shuanghuan
# Models for shuanghuan : ['Shuanghuan Ceo']
# Scraping models for simca
# Models for simca : ['Simca 1000', 'Simca 1100', 'Simca 1200', 'Simca 1300', 'Simca 1301', 'Simca 1500', 'Simca 1501', 'Simca 5', 'Simca 6', 'Simca 8', 'Simca 9', 'Simca Ariane', 'Simca Aronde', 'Simca Beaulieu', 'Simca Chambord', 'Simca Elysee', 'Simca Etoile', 'Simca Marly', 'Simca Monaco', 'Simca Monthlery', 'Simca Oceane', 'Simca P60', 'Simca Plein Ciel', 'Simca Presidence', 'Simca Regence', 'Simca Trianon', 'Simca Vedette', 'Simca Versailles']
# Scraping models for singer
# Models for singer : ['Singer Chamois', 'Singer Gazelle', 'Singer Vogue']
# Scraping models for sivax
# Models for sivax : ['Sivax Izana Concept']
# Scraping models for skoda
# Models for skoda : ['Skoda Elroq', 'Skoda Enyaq', 'Skoda Fabia', 'Skoda Kamiq', 'Skoda Karoq', 'Skoda Kodiaq', 'Skoda Octavia', 'Skoda Scala', 'Skoda Superb', 'Skoda 100', 'Skoda 105', 'Skoda 110', 'Skoda 120', 'Skoda 130', 'Skoda Citigo', 'Skoda Coupe', 'Skoda Favorit', 'Skoda Favorit Pick Up', 'Skoda Felicia', 'Skoda Rapid', 'Skoda Roomster', 'Skoda Yeti', 'Skoda Joyster', 'Skoda Missionl Concept', 'Skoda Vision C Concept', 'Skoda Vision E Concept', 'Skoda Vision Rs Concept', 'Skoda Vision X Concept', 'Skoda Visions Concept']
# Scraping models for smart
# Models for smart : ['Smart Fortwo 3 Cabriolet', 'Smart #1', 'Smart #3', 'Smart Fortwo', 'Smart Crossblade', 'Smart Forfour', 'Smart Roadster', 'Smart Smart', 'Smart Concept Forstars', 'Smart Crosstown', 'Smart For-us', 'Smart Forease+ Concept', 'Smart Forspeed Concept', 'Smart Fortwo Vision Eq Concept', 'Smart Forvision']
# Scraping models for sms
# Models for sms : ['Sms Tilbury']
# Scraping models for sovamag
# Models for sovamag : ['Sovamag Tc 10']
# Scraping models for spectre
# Models for spectre : ['Spectre R42']
# Scraping models for spyker
# Models for spyker : ['Spyker C12 Zagato', 'Spyker C8', 'Spyker C8 Aileron', 'Spyker C8 Laviolette', 'Spyker D8 Pekin To Paris', 'Spyker B6 Venator', 'Spyker D12 Concept']
# Scraping models for srt
# Models for srt : ['Srt Viper']
# Scraping models for ssangyong
# Models for ssangyong : ['Ssangyong Korando', 'Ssangyong Musso', 'Ssangyong Rexton', 'Ssangyong Tivoli', 'Ssangyong Tivoli Xlv', 'Ssangyong Actyon', 'Ssangyong Actyon Sports', 'Ssangyong Family', 'Ssangyong Kyron', 'Ssangyong Rodius', 'Ssangyong Sut-1', 'Ssangyong Xlv', 'Ssangyong C200 Concept', 'Ssangyong E-xiv Concept', 'Ssangyong Siv-1 Concept', 'Ssangyong Siv-2 Concept', 'Ssangyong Xiv-1', 'Ssangyong Xiv-2']
# Scraping models for ssc
# Models for ssc : ['Ssc Tuatara']
# Scraping models for studebaker
# Models for studebaker : ['Studebaker Avanti', 'Studebaker Champion', 'Studebaker Commander', 'Studebaker Cruiser', 'Studebaker Daytona', 'Studebaker Golden', 'Studebaker Golden Hawk', 'Studebaker Hawk', 'Studebaker Land Cruiser', 'Studebaker Lark', 'Studebaker President', 'Studebaker Regal', 'Studebaker Wagonaire']
# Scraping models for stutz
# Models for stutz : ['Stutz Blackhawk']
# Scraping models for subaru
# Models for subaru : ['Subaru Crosstrek', 'Subaru Evoltis', 'Subaru Forester', 'Subaru Impreza', 'Subaru Outback', 'Subaru Solterra', 'Subaru Xv', 'Subaru B9 Tribeca', 'Subaru Brz', 'Subaru Justy', 'Subaru Legacy', 'Subaru Levorg', 'Subaru Svx', 'Subaru Trezia', 'Subaru Tribeca', 'Subaru Vanille', 'Subaru Wrx Sti', 'Subaru B11s', 'Subaru B9 Scrambler', 'Subaru Hm-01', 'Subaru Impreza Concept', 'Subaru Legacy Concept', 'Subaru R1e', 'Subaru St-x', 'Subaru Viziv 2 Concept', 'Subaru Viziv Concept', 'Subaru Wrx Concept']
# Scraping models for sunbeam
# Models for sunbeam : ['Sunbeam 1000', 'Sunbeam 1100', 'Sunbeam 1250', 'Sunbeam 1300', 'Sunbeam 1600', 'Sunbeam 80', 'Sunbeam 90', 'Sunbeam Alpine', 'Sunbeam Avenger', 'Sunbeam Californian', 'Sunbeam Chamois', 'Sunbeam Lotus', 'Sunbeam Rapier', 'Sunbeam Sceptre', 'Sunbeam Stiletto', 'Sunbeam Tiger', 'Sunbeam Vogue']
# Scraping models for suzuki
# Models for suzuki : ['Suzuki Across', 'Suzuki Ignis', 'Suzuki Jimny', 'Suzuki S-cross', 'Suzuki Swace', 'Suzuki Swift', 'Suzuki Vitara', 'Suzuki Alto', 'Suzuki Baleno', 'Suzuki Carry', 'Suzuki Celerio', 'Suzuki Grand Vitara', 'Suzuki Grand Vitara Xl-7', 'Suzuki Kizashi', 'Suzuki Liana', 'Suzuki Samurai', 'Suzuki Splash', 'Suzuki Sx4', 'Suzuki Sx4 S-cross', 'Suzuki Wagon R+', 'Suzuki X90', 'Suzuki Grand Vitara Sport Evolution', 'Suzuki Im-4 Concept', 'Suzuki Iv-4 Concept', 'Suzuki Regina Concept', 'Suzuki S-cross Concept', 'Suzuki Splash Concept']
# Scraping models for talbot
# Models for talbot : ['Talbot Dc 10']
# Scraping models for talbot-simca
# Models for talbot-simca : ['Talbot Simca 1000', 'Talbot Simca 1100', 'Talbot Simca 1301', 'Talbot Simca 1307', 'Talbot Simca 1308', 'Talbot Simca 1309', 'Talbot Simca 15 Cv', 'Talbot Simca 1510', 'Talbot Simca Chrysler', 'Talbot Simca Horizon', 'Talbot Simca Lago', 'Talbot Simca Samba', 'Talbot Simca Solara', 'Talbot Simca Tagora']
# Scraping models for tata
# Models for tata : ['Tata Telcoline', 'Tata Xenon', 'Tata Nano']
# Scraping models for teilhol
# Models for teilhol : ['Teilhol Tangara']
# Scraping models for tesla
# Models for tesla : ['Tesla Cybertruck', 'Tesla Model 3', 'Tesla Model S', 'Tesla Model X', 'Tesla Model Y', 'Tesla Roadster', 'Tesla Model S Concept']
# Scraping models for think
# Models for think : ['Think City']
# Scraping models for toyota
# Models for toyota : ['Toyota Auris', 'Toyota Avensis', 'Toyota Aygo X', 'Toyota Bz4x', 'Toyota C-hr', 'Toyota Camry', 'Toyota Corolla', 'Toyota Corolla Cross', 'Toyota Gr 86', 'Toyota Highlander', 'Toyota Hilux', 'Toyota Land Cruiser', 'Toyota Mirai', 'Toyota Prius', 'Toyota Prius+', 'Toyota Proace', 'Toyota Proace City', 'Toyota Proace City Verso', 'Toyota Proace Verso', 'Toyota Rav 4', 'Toyota Supra', 'Toyota Yaris', 'Toyota Yaris Cross', 'Toyota 1000', 'Toyota 2000 Gt', 'Toyota 4runner', 'Toyota Avensis Verso', 'Toyota Aygo', 'Toyota Carina', 'Toyota Carina E', 'Toyota Carina Ii', 'Toyota Celica', 'Toyota Corolla Verso', 'Toyota Corona', 'Toyota Cressida', 'Toyota Crown', 'Toyota Dyna', 'Toyota Fj Cruiser', 'Toyota Fun Cruiser', 'Toyota Gt86', 'Toyota Hi Ace', 'Toyota Iq', 'Toyota Land Cruiser Sw', 'Toyota Lite Ace', 'Toyota Model F', 'Toyota Mr', 'Toyota Paseo', 'Toyota Picnic', 'Toyota Previa', 'Toyota Starlet', 'Toyota Tacoma', 'Toyota Tercel', 'Toyota Tundra', 'Toyota Urban Cruiser', 'Toyota Verso', 'Toyota Verso-s', 'Toyota Yaris Verso', 'Toyota Auris Concept', 'Toyota Aygo X Prologue', 'Toyota C-hr Concept', 'Toyota C-hr Concept 2', 'Toyota Cs&amp;s', 'Toyota D-4d 180 Concept', 'Toyota Endo', 'Toyota Es3', 'Toyota Fchv-4', 'Toyota Fine-n', 'Toyota Fine-s', 'Toyota Ft-86', 'Toyota Ft-86 (2)', 'Toyota Ft-hs', 'Toyota Fxs', 'Toyota Gt86 Cabriolet Concept', 'Toyota I-road Concept', 'Toyota I-tril Concept', 'Toyota I-unit', 'Toyota Iq Concept', 'Toyota Mtrc', 'Toyota Pod', 'Toyota Prius C Concept', 'Toyota Uuv']
# Scraping models for trabant
# Models for trabant : ['Trabant 601', 'Trabant P50']
# Scraping models for triumph
# Models for triumph : ['Triumph 1300', 'Triumph 2,5 Pi', 'Triumph 2000', 'Triumph 2500', 'Triumph Acclaim', 'Triumph Dolomite', 'Triumph Gt6', 'Triumph Herald', 'Triumph Mayflower', 'Triumph Renow', 'Triumph Spitfire', 'Triumph Stag', 'Triumph Toledo', 'Triumph Tr 2', 'Triumph Tr 250', 'Triumph Tr 3', 'Triumph Tr 4', 'Triumph Tr 5', 'Triumph Tr 6', 'Triumph Tr 7', 'Triumph Tr 8', 'Triumph Vitesse']
# Scraping models for tvr
# Models for tvr : ['Tvr 1600 M', 'Tvr 2500 M', 'Tvr 3000 M', 'Tvr 350', 'Tvr Cerbera', 'Tvr Chimaera', 'Tvr Grantura', 'Tvr Griffith', 'Tvr S', 'Tvr S4', 'Tvr Sagaris', 'Tvr Taimar', 'Tvr Tamora', 'Tvr Tuscan', 'Tvr Vixen']
# Scraping models for ultima
# Models for ultima : ['Ultima Gtr', 'Ultima Sports']
# Scraping models for umm
# Models for umm : ['Umm Alter']
# Scraping models for vaillante
# Models for vaillante : []
# Scraping models for van-hool
# Models for van-hool : ['Van Hool A320', 'Van Hool Eos', 'Van Hool Eos 100']
# Scraping models for vanden-plas
# Failed to fetch: 404
# Models for vanden-plas : []
# Scraping models for vauxhall
# Models for vauxhall : ['Vauxhall 10-4', 'Vauxhall 12-4', 'Vauxhall Carlton', 'Vauxhall Cavalier', 'Vauxhall Chevette', 'Vauxhall Cresta', 'Vauxhall Royale', 'Vauxhall Velox', 'Vauxhall Victor', 'Vauxhall Viva', 'Vauxhall Vx', 'Vauxhall Wyvern']
# Scraping models for velam
# Models for velam : ['Velam Isetta']
# Scraping models for venturi
# Models for venturi : ['Venturi 300 Atlantique', 'Venturi 400 Gt', 'Venturi Coupe 260', 'Venturi Fetish', 'Venturi Transcup', 'Venturi America', 'Venturi Antarctica', 'Venturi Astrolab', 'Venturi Eclectic', 'Venturi Gt3 Concept']
# Scraping models for veritas
# Models for veritas : []
# Scraping models for vespa
# Models for vespa : ['Vespa 400']
# Scraping models for vinfast
# Models for vinfast : ['Vinfast Lux A2.0', 'Vinfast Lux Sa2.0', 'Vinfast Vf 7', 'Vinfast Vf 8', 'Vinfast Vf 9', 'Vinfast Vf E35']
# Scraping models for virago
# Models for virago : []
# Scraping models for volkswagen
# Models for volkswagen : ['Volkswagen Id.2', 'Volkswagen Amarok', 'Volkswagen Arteon', 'Volkswagen Caddy', 'Volkswagen California', 'Volkswagen Caravelle', 'Volkswagen Crafter', 'Volkswagen Golf', 'Volkswagen Golf Sportsvan', 'Volkswagen Grand California', 'Volkswagen Id. Buzz', 'Volkswagen Id.3', 'Volkswagen Id.4', 'Volkswagen Id.5', 'Volkswagen Id.7', 'Volkswagen Multivan', 'Volkswagen Passat', 'Volkswagen Polo', 'Volkswagen T-cross', 'Volkswagen T-roc', 'Volkswagen Taigo', 'Volkswagen Tiguan', 'Volkswagen Tiguan Allspace', 'Volkswagen Touareg', 'Volkswagen Touran', 'Volkswagen Transporter', 'Volkswagen Up!', 'Volkswagen 1200', 'Volkswagen 1300', 'Volkswagen 1302', 'Volkswagen 1303', 'Volkswagen 1500', 'Volkswagen 1600', 'Volkswagen 181', 'Volkswagen 411', 'Volkswagen Bora', 'Volkswagen Buggy', 'Volkswagen Cc', 'Volkswagen Coccinelle', 'Volkswagen Combi', 'Volkswagen Corrado', 'Volkswagen Derby', 'Volkswagen Eos', 'Volkswagen Fox', 'Volkswagen Golf Plus', 'Volkswagen Iltis', 'Volkswagen Jetta', 'Volkswagen K70', 'Volkswagen Karman Ghia', 'Volkswagen Lt', 'Volkswagen Lt Combi', 'Volkswagen Lupo', 'Volkswagen New Beetle', 'Volkswagen Passat Cc', 'Volkswagen Phaeton', 'Volkswagen Scirocco', 'Volkswagen Sharan', 'Volkswagen Variant', 'Volkswagen Vento', 'Volkswagen Xl1', 'Volkswagen Budd-e Concept', 'Volkswagen Bulli', 'Volkswagen Cross Coupe', 'Volkswagen E-bugster', 'Volkswagen I.d. Concept', 'Volkswagen I.d. Crozz Ii Concept', 'Volkswagen I.d. Vizzion Concept', 'Volkswagen Id. Xtreme Concept', 'Volkswagen Id.life Concept', 'Volkswagen Iroc', 'Volkswagen Nils', 'Volkswagen Sport Coupe Concept Gte', 'Volkswagen T-cross Breeze Concept', 'Volkswagen T-roc Concept', 'Volkswagen Taigun Concept', 'Volkswagen Xl Sport Concept', 'Volkswagen Xl1 Concept', 'Volkswagen Id.6', 'Volkswagen Routan']
# Scraping models for volteis
# Models for volteis : ['Volteis X2', 'Volteis X4']
# Scraping models for volvo
# Models for volvo : ['Volvo Em90', 'Volvo C40', 'Volvo Ex30', 'Volvo Ex40', 'Volvo Ex90', 'Volvo Fm9', 'Volvo S60', 'Volvo S90', 'Volvo V60', 'Volvo V60 Cross Country', 'Volvo V90', 'Volvo Xc40', 'Volvo Xc60', 'Volvo Xc90', 'Volvo 121', 'Volvo 122', 'Volvo 123', 'Volvo 142', 'Volvo 144', 'Volvo 145', 'Volvo 164', 'Volvo 240', 'Volvo 244', 'Volvo 245', 'Volvo 262', 'Volvo 264', 'Volvo 265', 'Volvo 340', 'Volvo 343', 'Volvo 360', 'Volvo 440', 'Volvo 460', 'Volvo 480', 'Volvo 66', 'Volvo 740', 'Volvo 760', 'Volvo 780', 'Volvo 850', 'Volvo 940', 'Volvo 960', 'Volvo C30', 'Volvo C70', 'Volvo F610', 'Volvo P1800', 'Volvo Pv544', 'Volvo S40', 'Volvo S70', 'Volvo S80', 'Volvo V40', 'Volvo V40 Cross Country', 'Volvo V50', 'Volvo V70', 'Volvo V90 Cross Country', 'Volvo Xc70', 'Volvo 3cc', 'Volvo Acc', 'Volvo Acc 2', 'Volvo C30 Recharge Concept', 'Volvo Concept Coupe', 'Volvo Concept Estate', 'Volvo Ecc', 'Volvo Pcc', 'Volvo Pcc Break', 'Volvo S60 Concept', 'Volvo Scc', 'Volvo Vcc', 'Volvo Vesc', 'Volvo Ycc']
# Scraping models for volvo-trucks
# Models for volvo-trucks : []
# Scraping models for wallys-car
# Models for wallys-car : ['Wallys Car Izis']
# Scraping models for westfield
# Models for westfield : ['Westfield Fw300', 'Westfield Super Seven', 'Westfield Zei']
# Scraping models for wiesmann
# Models for wiesmann : ['Wiesmann Gt', 'Wiesmann Roadster']
# Scraping models for willys
# Models for willys : ['Willys Jeep']
# Scraping models for wolseley
# Models for wolseley : ['Wolseley 1100', 'Wolseley 1300', 'Wolseley 1500', 'Wolseley Hornet', 'Wolseley Six']
# Scraping models for xev
# Failed to fetch: 404
# Models for xev : []
# Scraping models for xiaomi
# Failed to fetch: 404
# Models for xiaomi : []
# Scraping models for xinyang
# Models for xinyang : ['Xinyang Electric Utility']
# Scraping models for xpeng
# Failed to fetch: 404
# Models for xpeng : []
# Scraping models for yangwang
# Failed to fetch: 404
# Models for yangwang : []
# Scraping models for zagato
# Models for zagato : ['Zagato Milano']
# Scraping models for zap
# Models for zap : []
# Scraping models for zastava
# Models for zastava : ['Zastava 1100', 'Zastava 1300', 'Zastava Yugo']
# Scraping models for zeekr
# Failed to fetch: 404
# Models for zeekr : []
# Scraping models for zenn
# Models for zenn : []
# Scraping models for zenvo
# Models for zenvo : []

# %%
'''
import requests
from bs4 import BeautifulSoup

# Function to scrape models from the given URL
def scrape_models(url):
    models = []

    # Make a GET request to the URL
    response = requests.get(url)
    if response.status_code == 200:
        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all div elements with class "txtModeleGalerie"
        div_elements = soup.find_all("div", class_="txtModeleGalerie")
        
        # Extract model names
        for div in div_elements:
            # Find the a tag inside the div
            a_tag = div.find("a")
            if a_tag:
                # Extract model name from p tag
                p_tag = a_tag.find("p", class_="h3")
                if p_tag:
                    model_name = p_tag.get_text(strip=True)
                    models.append(model_name)

    return models

# Example link
url = "https://www.caradisiac.com/auto--ad-tramontana/modeles/"

# Scrape models from the provided link
models = scrape_models(url)

# Print the extracted models
print("Models for Bellier:", models)
'''

# %%
'''
# Create a new column 'models' in the DataFrame
df['models'] = ''

# Iterate over each brand name and scrape models
for index in range(len(df)):
    for brand_name in brand_names:
        models = scrape_models(brand_name)
    
    # Update the 'models' column with the list of models for the current brand
    df.at[index, 'models'] = models

# Display the updated DataFrame
print(df)
'''

# %%
import pandas as pd

# List to store all scraped models
all_models = []

# Iterate over each brand name and scrape models
for brand_name in brand_names:
    models = scrape_models(brand_name)
    # Extend the list of all models with the models scraped for the current brand
    all_models.extend(models)

# Create a DataFrame with a column 'models' containing all scraped models
df_models = pd.DataFrame({'models': all_models})
# Out:
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 410
# Failed to fetch: 404
# Failed to fetch: 410
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
# Failed to fetch: 404
#                         models
# 0                   Abarth 500
# 1                  Abarth 600e
# 2                   Abarth 124
# 3          Abarth Grande Punto
# 4             Abarth Punto Evo
# ...                        ...
# 3322  Xinyang Electric Utility
# 3323             Zagato Milano
# 3324              Zastava 1100
# 3325              Zastava 1300
# 3326              Zastava Yugo
#
# [3327 rows x 1 columns]

# %%
# Display the DataFrame
df_models
# Out:
#                         models
# 0                   Abarth 500
# 1                  Abarth 600e
# 2                   Abarth 124
# 3          Abarth Grande Punto
# 4             Abarth Punto Evo
# ...                        ...
# 3322  Xinyang Electric Utility
# 3323             Zagato Milano
# 3324              Zastava 1100
# 3325              Zastava 1300
# 3326              Zastava Yugo
#
# [3327 rows x 1 columns]

# %%
df_models["brands"] = ''
for i in range(len(df_models)):
    model = df_models["models"][i].split()
    df_models["brands"][i] = model[0]

# %%
df_models
# Out:
#                         models   brands models_without_brand
# 0                   Abarth 500   Abarth                  500
# 1                  Abarth 600e   Abarth                 600e
# 2                   Abarth 124   Abarth                  124
# 3          Abarth Grande Punto   Abarth         Grande Punto
# 4             Abarth Punto Evo   Abarth            Punto Evo
# ...                        ...      ...                  ...
# 3322  Xinyang Electric Utility  Xinyang     Electric Utility
# 3323             Zagato Milano   Zagato               Milano
# 3324              Zastava 1100  Zastava                 1100
# 3325              Zastava 1300  Zastava                 1300
# 3326              Zastava Yugo  Zastava                 Yugo
#
# [3327 rows x 3 columns]

# %%
# Extracting models without brand indication
df_models['models_without_brand'] = df_models['models'].apply(lambda x: ' '.join(x.split()[1:]))

# %%
#detecting duplicates
df_models.duplicated(subset= ['models']).sum()
# Out:
# 1

# %%
print(df_models[df_models.duplicated(subset='models', keep=False)])
# Out:
#            models   brands models_without_brand
# 2500  Porsche 918  Porsche                  918
# 2509  Porsche 918  Porsche                  918

# %%
df_models.drop_duplicates(subset= ['models'],keep= 'first', inplace= True)

# %%
df_models
# Out:
#                         models   brands models_without_brand
# 0                   Abarth 500   Abarth                  500
# 1                  Abarth 600e   Abarth                 600e
# 2                   Abarth 124   Abarth                  124
# 3          Abarth Grande Punto   Abarth         Grande Punto
# 4             Abarth Punto Evo   Abarth            Punto Evo
# ...                        ...      ...                  ...
# 3322  Xinyang Electric Utility  Xinyang     Electric Utility
# 3323             Zagato Milano   Zagato               Milano
# 3324              Zastava 1100  Zastava                 1100
# 3325              Zastava 1300  Zastava                 1300
# 3326              Zastava Yugo  Zastava                 Yugo
#
# [3326 rows x 3 columns]

# %%
# Specify the file path and name
file_path = 'C:/Users/ASUS/Desktop/stage pfe/car_brands_models.csv'

# Save the DataFrame to a CSV file
df_models.to_csv(file_path, index=False)
